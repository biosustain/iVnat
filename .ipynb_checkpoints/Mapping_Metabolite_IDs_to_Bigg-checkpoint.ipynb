# %%
from pandas import read_csv, DataFrame
import pandas as pd
import os
import re #Both patterns and strings to be searched can be Unicode strings as well as 8-bit strings.
import math
import cobra
import cobra.test
from __future__ import print_function
from os.path import join
from cobra.io import write_sbml_model

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
data_dir = "/Users/lizrad/Dev/iVnat"
print("files found: ")
print(", ".join(i for i in os.listdir(data_dir) if i.startswith("iVnat")))
model=cobra.io.read_sbml_model(join(data_dir, "iVnat.xml"))
#model=cobra.io.read_legacy_sbml("C:\\Users\Asus\Documents\Vibrio_project_literature\GCF_001456255.1_rast_metabolic_model.SBML\GCF_001456255.1_rast_metabolic_model.xml")
model

# %% [markdown]
# ### Read chem_xref

# %%
chem_xref = read_csv("/Users/lizrad/Dev/iVnat/chem_xref.tsv" , sep='\t' , low_memory=False)
chem_xref

# %% [markdown]
# ### Bigg IDs to dict key

# %%
df_bigg = chem_xref.loc[2:10216,'XREF':'MNX_ID']
pivoted_bigg = df_bigg.pivot_table(index='XREF',columns='XREF_ID',values='MNX_ID',aggfunc = lambda x: x)
pivoted_bigg
#pivoted_bigg=pivoted_bigg.drop(['metanetx'])
chem_xref_MNX_bigg_dict = pivoted_bigg.to_dict('index')
chem_xref_MNX_bigg_dict2 = chem_xref_MNX_bigg_dict['bigg']
chem_xref_MNX_bigg_dict2

# %% [markdown]
# ### Bigg IDs to annotation field

# %%
for met in model.metabolites:
    data=''
    if 'metanetx.chemical' in met.annotation:
        data=met.annotation['metanetx.chemical'] 
        
        for xref in chem_xref_MNX_bigg_dict2.keys():
            if chem_xref_MNX_bigg_dict2[xref]==data:
                met.annotation['bigg.metabolite']=xref
                print(met.annotation)

# %% [markdown]
# ### Check for multiplicatives among the Bigg IDs

# %%
dupl_bigg = {}
for met in model.metabolites:
    if "bigg.metabolite" not in met.annotation.keys():
        continue
    if met.id in ["cpd00261_c0", "cpd06227_c0", "cpd03572_c0", "cpd02446_c0","cpd02572_c0", "cpd01466_c0" ]:
        pass
    else:    
        if met.annotation["bigg.metabolite"] not in dupl_bigg.keys():
            dupl_bigg.setdefault(met.annotation["bigg.metabolite"],[met.id])
        else:
            dupl_bigg[met.annotation["bigg.metabolite"]].append(met.id)

# %%
for ls in dupl_bigg.values():
    if len(ls) > 1:
        print(ls)

# %%
for ls in dupl_bigg.values():
    if len(ls) > 1:
        #print(ls)
        x=[]
        y=[]
        for members in ls: 
            main_id, comp =members.split("_")
            x.append(main_id)
            y.append(comp)
        if not x[0]==x[1]:
            print(x,y)
            for pair in zip(x,y):
                print(len(model.metabolites.get_by_id(pair[0]+"_"+pair[1]).reactions))

# %% [markdown]
# ### Change the MNXM IDs to Bigg IDs

# %% [markdown]
# With the newest version of the model where bigg IDs are in the annotation field.

# %%
data_dir = "/Users/lizrad/Documents/Vibrio_folder"
print("files found: ")
print(", ".join(i for i in os.listdir(data_dir) if i.startswith("iVnat")))
model_new=cobra.io.read_sbml_model(join(data_dir, "iVnat_newbigg.xml"))
#model=cobra.io.read_legacy_sbml("C:\\Users\Asus\Documents\Vibrio_project_literature\GCF_001456255.1_rast_metabolic_model.SBML\GCF_001456255.1_rast_metabolic_model.xml")
model_new
# Out:
# files found:
# iVnat_newbigg.xml, iVnatReport.html, iVnat_bigg.xml, iVnat_newbigg.json, iVnat_gapfill_glu.xml, iVnat_20180817.xml
# <Model GCF_001456255_1_rast_metabolic_model at 0x118df6198>

# %% [markdown]
# just choosing the first bigg id from the list (not ideal!!!!)
#
# there are 63 metabolites which have multiple bigg id

# %%
with_bigg=0
for met in model_new.metabolites:
    print(met.id)
    split, compartment=met.id.rsplit("_", 1)
    if "bigg.metabolite" not in met.annotation.keys():
        continue
    if met.id in ["cpd00261_c0", "cpd06227_c0", "cpd03572_c0", "cpd02446_c0","cpd02572_c0", "cpd01466_c0" ]:
        pass
    else: 
        with_bigg+=1
        if type(met.annotation["bigg.metabolite"]) == list:
            print("whole annotation:" ,met.annotation['bigg.metabolite'])
            
            met.id=met.annotation['bigg.metabolite'][0]+ '_' + compartment
        else: 
            met.id=met.annotation['bigg.metabolite']+ '_' + compartment
            
            
    #if met.id.startswith('cpd'):
        
        print(met.id)
      

        
        model_new.repair()
       # print(met.id)

# %%
for met in model_new.metabolites:
    met.id=met.id[:-1]
    print(met.id)
# Out:
# 4abz_c
# 2ahhmd_c
# ppi_c
# h_c
# dhpt_c
# atp_c
# gly_c
# glucys_c
# adp_c
# pi_c
# gthrd_c
# lpam_c
# 2mhop_c
# thmpp_c
# 2mpdhl_c
# imp_c
# prpp_c
# hxan_c
# nad_c
# 12ppd__R_c
# nadh_c
# lald__D_c
# h2o_c
# CPD-576_c
# CE1787_c
# Carboxylates_c
# amet_c
# s_c
# dtbt_c
# met__L_c
# btn_c
# dad_5_c
# h_e
# adn_e
# adn_c
# 5-L-GLUTAMYL-L-AMINO-ACID_c
# 5oxpro_c
# L-Amino-Acids_c
# Lactosyl-Ceramides_c
# gal_c
# gluside_cho_c
# accoa_c
# ser__L_c
# coa_c
# acser_c
# cmp_c
# cdp_c
# fum_e
# fum_c
# uacgam_c
# uagmda_c
# udp_c
# uaagmda_c
# ichor_c
# pyr_c
# 23ddhb_c
# MNXM3273_c
# amp_c
# MNXM5746_c
# glu__L_c
# cys__L_c
# fad_c
# mal__L_c
# oaa_c
# fadh2_c
# dcdp_c
# dctp_c
# co2_c
# pep_c
# no2_e
# no2_c
# 4hpro_LT_c
# CIS-4-HYDROXY-D-PROLINE_c
# 2ahethmpp_c
# HC00682_c
# MNXM5622_c
# MNXM8308_c
# orn_e
# orn_c
# malt_c
# glc__D_c
# cit_c
# icit_c
# tcynt_c
# nh3_c
# CARBONYL-SULFIDE_c
# dtdp4d6dg_c
# dtdp4d6dm_c
# 3hhdcoa_c
# 3ohdcoa_c
# UDP-APIOSE_c
# APIGENIN-7-O-BETA-D-GLUCOSIDE_c
# 7-O-BETA-D-APIOFURANOSYL-12-BETA-D-GLU_c
# N-METHYLHYDANTOIN_c
# dhap_c
# lcts_c
# cdpglc_c
# cdp4dh6doglc_c
# quln_c
# iasp_c
# hmgth_c
# Sfglutth_c
# 5mta_c
# ade_c
# 5mtr_c
# MNXM8382_c
# MNXM11399_c
# ara5p_c
# L-DOPACHROME_c
# 56-DIHYDROXYINDOLE-2-CARBOXYLATE_c
# MNXM96971_c
# Nucleoside-Diphosphates_c
# L_alagly_e
# L_alagly_c
# etha_c
# acald_c
# CPD-17323_c
# CPD-17322_c
# acgam_c
# acgam1p_c
# mmcoa__S_c
# ppcoa_c
# CPD-12708_c
# CPD-12709_c
# duri_e
# duri_c
# e4p_c
# 4per_c
# ala_L_Thr__L_e
# ala_L_Thr__L_c
# 4hbald_c
# 4hbz_c
# 2mop_c
# ppi_e
# orot5p_c
# ump_c
# rbl__D_c
# 4mpetz_c
# 2mahmp_c
# thmmp_c
# 2ddecg3p_c
# DODECANOATE_c
# 5mthf_c
# mlthf_c
# mhpglu_c
# hpglu_c
# datp_c
# uri_c
# dadp_c
# MNXM147350_c
# pa141_c
# ala_L_glu__L_e
# ala_L_glu__L_c
# csn_c
# ura_c
# lipa_c
# adphep_LD_c
# hlipa_c
# salcn_e
# salcn6p_c
# xan_c
# MNXM7956_c
# MNXM6573_c
# CPD-61_c
# PROPIONATE_c
# MNXM7607_c
# stcoa_c
# MNXM5744_c
# 3ig3p_c
# g3p_c
# indole_c
# 1ddecg3p_c
# TRANS-2-CHLORO-4-CARBOXYMETHYLENEBUT-2-E_c
# CIS-2-CHLORO-4-CARBOXYMETHYLENEBUT-2-EN-_c
# lipidAds_c
# lipidA_c
# fald_c
# dha_c
# CPD-34_c
# KIEVITONE-CPD_c
# kdo8p_c
# dhlpro_c
# lpro_c
# MNXM6580_c
# gly_phe__L_c
# phe__L_c
# 4pasp_c
# Lcyst_c
# pro__L_e
# na1_e
# pro__L_c
# na1_c
# cdpdtdec7eg_c
# pyam5p_c
# pydx5p_c
# ibt_c
# ISOBUTANOATE-P_c
# 2odec11eg3p_c
# MNXM65309_c
# all__D_c
# all6p_c
# camp_c
# Butanoyl-ACPs_c
# 3ohexACP_c
# his__L_c
# urcan_c
# MNXM5873_c
# MNXM5874_c
# urate_c
# 5hiu_c
# HEXANOYL-COA_c
# 3oocoa_c
# maltttr_c
# maltpt_c
# MNXM2646_c
# MNXM2646_e
# SINAPALDEHYDE_c
# SINAPATE_c
# tsul_c
# ac_c
# so3_c
# gln__L_c
# asn__L_c
# 2mbcoa_c
# 2mb2coa_c
# cdpdtdecg_c
# MNXM92581_c
# g1p_c
# adpglc_c
# HC01435_c
# HC00695_c
# MNXM90163_e
# MNXM90163_c
# cdpdhdec9eg_c
# MNXM92576_c
# g3pg_c
# CPD-10613_c
# CPD-10879_c
# 3c3hmp_c
# CPD-580_c
# ala_B_c
# h2co3_c
# btnCCP_c
# cbtnCCP_c
# 2ameph_c
# MNXM47346_c
# MNXM92046_c
# 3hpimcoa_c
# 1-ALKENYL-2-ACYLGLYCEROL_c
# 35cgmp_c
# pram_c
# MNXM10122_c
# MNXM12665_c
# 2p4c2me_c
# ak2g_cho_c
# Alkyl-acyl-gly-P-EtOH-amines_c
# MNXM6298_c
# MNXM162320_c
# cdpdodecg_c
# D-BETA-D-HEPTOSE-17-DIPHOSPHATE_c
# gmhep1p_c
# prlp_c
# MNXM8377_c
# MNXM11359_c
# thym_c
# 2dr1p_c
# 3hpalmACP_c
# 3opalmACP_c
# MNXM5477_c
# BUTANEDIOL_c
# ACETOIN_c
# HC01161_c
# 2ddglcn_c
# CPD-343_c
# MNXM8218_c
# MNXM9655_c
# lipoate_c
# CE5656_c
# cyan_c
# galt_e
# galt1p_c
# 3hpcoa_c
# 3mbzald_c
# m_tol_c
# taur_e
# 4izp_c
# forglu_c
# CPD-14426_c
# CPD-13792_c
# 4abut_c
# sucsal_c
# codscl8x_c
# MNXM90961_c
# MNXM163919_c
# CPD-13833_c
# 16-METHOXY-23-DIHYDRO-3-HYDROXYTABERSON_c
# DEACETOXYVINDOLINE_c
# MNXM6281_c
# glycogen_c
# gly_phe__L_e
# MNXM147676_c
# orn__D_c
# gly_cys__L_c
# MNXM5743_c
# MNXM9623_c
# nebari_c
# purine_c
# MNXM42463_c
# 1tdec7eg3p_c
# MNXM83847_c
# CPD-8574_c
# ghb_c
# spmd_e
# SOLANESYL-PYROPHOSPHATE_c
# NONAPRENYL-4-HYDROXYBENZOATE_c
# inoshp_c
# ppmi12346p_c
# cdpdddecg_c
# 2hdec9eg3p_c
# 12-DIACYL-3-O-ALPHA-D-GLUCOPYRANOSYL_c
# 12-DIACYL-3-O-ALPHA-D-GLUCOPYRANOSYL1_c
# 56dh5flura_c
# aflburppa_c
# 3hddecACP_c
# trp__L_c
# trypta_c
# agm_c
# cpppg3_c
# ser__L_e
# TAUROCYAMINE_c
# MNXM161585_c
# Alkyl-Hydro-Peroxides_c
# Alcohols_c
# MNXM8973_c
# Protein-Tyrosines_c
# Protein-tyrosine-phosphates_c
# chols_c
# MNXM10423_c
# MNXM10422_c
# pail34p_cho_c
# pail3p_cho_c
# MNXM4972_c
# CPD-15898_c
# pnto__R_e
# pnto__R_c
# aacald_c
# MNXM6614_c
# HYDROXYNAPHTHOATE_c
# lycop_c
# CPD-11447_c
# CPD-9424_c
# CPD-9425_c
# val__L_c
# 4ampm_c
# 6a2ohxnt_c
# 1pipdn2c_c
# CPD1G-2_c
# CPD1G-121_c
# pppn_c
# MNXM163340_c
# acmalt_c
# ala_L_gln__L_c
# u23ga_c
# lipidX_c
# btcoa_c
# BUTYRIC_ACID_c
# 2ombz_c
# 2ommb_c
# 4gudbutn_c
# malthx_c
# nmn_c
# rnam_c
# CE5866_c
# 23cump_c
# 3ump_c
# met__D_e
# met__D_c
# dutp_c
# dudp_c
# 2sephchc_c
# CPD-9923_c
# phom_c
# MNXM6798_c
# sucarg_c
# MNXM5245_c
# MNXM538_c
# MNXM2968_c
# MNXM10616_c
# din_e
# din_c
# tre6p_c
# g6p_c
# BETA-ALANYL-COA_c
# 3c2hmp_c
# 2ippm_c
# L-arabinopyranose_e
# 3c4mop_c
# MNXM7959_c
# 5dpmev_c
# MNXM146502_c
# malttr_e
# malttr_c
# no3_c
# L2aadp_c
# N-5S-5-AMINO-5-CARBOXYPENTANOYL-L-CY_c
# ppap_c
# xmp_c
# docoscoa_c
# DOCOSANOATE_c
# cit_e
# fe3_e
# sbt__D_e
# sbt6p_c
# Largn_c
# MNXM146748_c
# hhlipa_c
# CPD-17700_c
# cbl2_e
# cbl2_c
# PROPIONYL_ADENYLATE_c
# MNXM9603_c
# Acetyl-CoA-carboxylase-phosphate_c
# MNXM571_c
# CPD-9442_c
# CPD-9441_c
# CORTISOL_c
# CPD-417_c
# MNXM8022_c
# mev__R_c
# 5pmev_c
# gly_leu__L_c
# 2hdecg3p_c
# ala__D_e
# MNXM9700_c
# MNXM9698_c
# acACP_c
# actACP_c
# metox_c
# GUANIDOACETIC_ACID_c
# uaaGgla_c
# uaaGgtla_c
# MNXM8175_c
# btal_c
# 1btol_c
# cbp_c
# MNXM4910_c
# peamn_c
# pap_c
# hqn_c
# MNXM5588_c
# uama_c
# acoa_c
# adhap_hs_c
# fprica_c
# Primary-Alcohols_c
# Aldehydes_c
# 2pg_c
# Octanoyl-ACPs_c
# octa_c
# MNXM93065_c
# Myelin-N-o-methyl-arginines_c
# mi12356p_c
# dccoa_c
# MNXM56353_c
# ncam_c
# nac_c
# ugam_c
# UDP-D-GALACTOSAMINE_c
# hkntd_c
# 3-OH-BENZALDEHYDE_c
# 3-HYDROXYBENZOATE_c
# MNXM146503_c
# MNXM9670_c
# fgam_c
# gar_c
# CPD-7224_c
# MNXM11397_c
# MNXM7307_c
# 23dappa_c
# N3-OXALYL-L-23-DIAMINOPROPANOATE_c
# mi4p__D_c
# 3odcoa_c
# frmd_c
# u3hga_c
# 2mp2coa_c
# cpd03572_c
# MNXM96124_c
# MNXM16906_c
# r3mmal_c
# MNXM6818_c
# MNXM36570_c
# adprib_c
# MNXM9706_c
# mg2_e
# mg2_c
# Ssq23epx_c
# lanost_c
# MNXM8147_c
# 34dhbz_c
# CCbuttc_c
# 3hadpcoa_c
# oxadpcoa_c
# P-BENZOQUINONE_c
# CPD0-2298_c
# man_e
# man6p_c
# MNXM4381_c
# MNXM5008_c
# CDP-N-METHYLETHANOLAMIN_c
# MNXM147670_c
# 8aonn_c
# dann_c
# amob_c
# Glycerophosphodiesters_c
# MNXM158870_c
# crn_c
# sucglu_c
# Oleoyl-ACPs_c
# MNXM5865_c
# MNXM5866_c
# MNXM5125_c
# pran_c
# 2cpr5p_c
# etoh_c
# CPD-681_c
# MNXM5131_c
# MNXM6301_c
# pser__L_c
# MNXM7958_c
# HC01700_c
# MNXM6636_c
# cobalt2_c
# MNXM90295_c
# MNXM90529_c
# MNXM11358_c
# CPD-9038_c
# gdchola_c
# ohpb_c
# CPD-12885_c
# Citronellates_c
# ps160_c
# pe160_c
# CPD-14293_c
# doco13ac_c
# 5mcsn_c
# MNXM146500_c
# thex2eACP_c
# drib_e
# drib_c
# MNXM426_c
# 3hmoa_c
# 3mb2coa_c
# MNXM91691_c
# MNXM6822_c
# lys__D_c
# ERYTHRITOL_c
# D-ERYTHRITOL-4P_c
# cpd00261_c
# xu1p__D_c
# 5apru_c
# 3hbutACP_c
# GIBBERELLIN_c
# GIBBERELLIN-2-O-BETA-D-GLUCOSIDE_c
# CPD-13834_c
# CPD-13835_c
# MNXM5794_c
# MNXM8772_c
# RS-3-Sulfolactate_c
# MNXM147675_c
# lac__L_e
# pydx_c
# MNXM9621_c
# MNXM162249_c
# MNXM9382_c
# MNXM9691_c
# 5odhf2a_c
# 3hocoa_c
# CPD-161_c
# 6pgl_c
# VIOMYCIN_c
# VIOMYCIN-P_c
# u3aga_c
# 3ophb_c
# MNXM73074_c
# pencilca_c
# acac_c
# CPD-216_c
# CPD-303_c
# zymst_c
# fecost_c
# CPD-466_c
# MNXM7957_c
# MNXM613_c
# MNXM5869_c
# MNXM5870_c
# CPD-485_c
# tym_c
# conialdh_c
# fer_c
# 4mcat_c
# CPD-10656_c
# MNXM989_c
# ckdo_c
# 2dr5p_c
# 5prdmbz_c
# rdmbzi_c
# udpgalfur_c
# xu5p__L_c
# glyb_e
# 1-Alkyl-glycerol-3-phosphate_c
# MNXM91872_c
# MNXM5296_c
# selhcys_c
# 3oddcoa_c
# 4hthr_c
# ptth_c
# cysam_c
# neuspn_c
# CPD-11463_c
# MNXM90619_c
# HC01446_c
# HC01440_c
# MNXM10474_c
# thm_c
# 4mhetz_c
# saccrp__L_c
# sl26da_c
# sl2a6o_c
# HC01231_c
# trp__L_e
# MNXM146342_c
# MNXM6361_c
# CPD-10574_c
# CPD-12905_c
# CPD-12906_c
# MNXM146497_c
# CPD-2041_c
# for_e
# 2saa_c
# DIPHTHAMIDE_c
# CPD-12345_c
# adocbl_c
# 4hba_c
# grdp_c
# PROT-CYS_c
# DNA-6-O-Methyl-Guanines_c
# Protein-S-methyl-L-cysteine_c
# MNXM5722_c
# hmpscoa_c
# BENZOYLSUCCINYL-COA_c
# MNXM8671_e
# pg160_c
# MNXM6370_c
# so4_e
# D-galactopyranose-6-phosphate_c
# MNXM6600_c
# alpro_c
# 1p3h5c_c
# MNXM7308_c
# meoh_c
# Protein-Histidines_c
# MNXM90093_c
# 4mop_c
# CPD-7836_e
# MNXM5792_c
# MNXM8761_c
# cobalt2_e
# tmao_c
# MNXM162337_e
# tma_c
# 2dmmq8_e
# PHENYLACETALDOXIME_c
# PHENYLACETONITRILE_c
# metox_e
# 3hacoa_c
# 3oacoa_c
# 6dg_c
# ALPHA-L-GLUTAMYL-PHOSPHATE_c
# MNXM3990_c
# CPD0-2367_c
# 5flurimp_c
# INOSITOL-1-4-5-TRISPHOSPHATE_c
# btnso_c
# MNXM6074_c
# MNXM3835_c
# hxan_e
# CPD-12702_c
# VICIANOSE_c
# R-VICIANIN_c
# S-METHYL-3-PHOSPHO-1-THIO-D-GLYCERATE_c
# S-METHYL-1-THIO-D-GLYCERATE_c
# CPD-306_c
# gly_pro__L_e
# MNXM147672_c
# pant__R_c
# 2dhp_c
# acon_C_c
# 2-Acylglycero-Phosphocholines_c
# gam1p_c
# dmbzid_c
# MNXM5933_c
# MNXM9122_c
# MNXM3272_c
# MNXM7231_c
# sheme_c
# scl_c
# CPD-322_c
# 2aobut_c
# Alpha-D-aldose-1-phosphates_c
# ADP-Aldoses_c
# N2ACETYL-ALPHA-NP_c
# N-ACETYL-AAA-SEMIALDEHYDE_c
# stchs_c
# CPD-1131_c
# PHTHALATE_c
# ser__D_c
# mnl_c
# 3hmp_c
# MNXM92580_c
# MNXM146608_c
# 6tins5mp_c
# 6txan5mp_c
# dtdprmn_c
# MNXM94421_c
# MNXM8003_c
# CPD-8764_c
# CPD-10280_c
# TETRACOSANOATE_c
# MNXM6122_c
# CPD-6061_c
# MNXM6887_c
# MNXM6888_c
# MNXM147678_c
# malthx_e
# MNXM4550_c
# MNXM4549_c
# MNXM5793_c
# MNXM8765_c
# dkdi_c
# 2tdec7eg3p_c
# GALACTOSYLCERAMIDE-SULFATE_c
# allphn_c
# pre8_c
# hgbyr_c
# mbdg_c
# gly_leu__L_e
# cynt_e
# tyr__L_e
# MNXM147349_c
# dhf_c
# fol_c
# MNXM12593_c
# gullac_c
# guln__L_c
# CPD-574_c
# rmn_c
# CPD-563_c
# met_L_ala__L_c
# 2ohph_c
# 5flura_c
# MNXM10367_c
# k_c
# k_e
# DIOXOPIPERAZINE_c
# glygly_c
# MNXM11926_c
# GDP-D-GLUCOSE_c
# GLYCODEOXYCHOLIC_ACID_c
# MNXM6115_c
# MNXM6908_c
# 2-CL-MUCONATE_c
# 4-CARBOXYMETHYLENEBUT-2-EN-4-OLIDE_c
# o2_e
# dtpcudcpp_c
# D-GALACTONO-1-4-LACTONE_c
# galctn__D_c
# CPD-17105_e
# CPD-17105_c
# CPD-399_c
# CPD-1110_c
# uaagtmda_c
# chol_e
# 3hpppn_c
# 5-HYDROXY-TRYPTOPHAN_c
# srtn_c
# pphos_c
# 4mbzald_c
# p_tol_c
# MNXM162770_c
# ugmda_c
# CPD-11700_c
# CPD-4203_c
# CPD-10636_c
# MNXM5258_c
# MNXM7630_c
# 2dh3dgal6p_c
# sucbz_c
# CPD-7986_c
# CPD-501_c
# gly_glu__L_e
# MNXM146495_c
# val__L_e
# ddcacoa_c
# MNXM11217_c
# ala_L_gln__L_e
# didp_c
# ditp_c
# MNXM1225_c
# 6E8Z11Z14Z-5S-5-HYDROPEROXYCOSA-6_c
# C04805_c
# ura_e
# aproa_c
# 11-DEOXYCORTICOSTERONE_c
# 20-HYDROXY-3-OXOPREGN-4-EN-21-AL_c
# MNXM92585_c
# MNXM93816_c
# NARINGENIN-CMPD_c
# CPD-9440_c
# retpalm_11_cis_c
# HC01104_c
# MNXM7305_c
# met_L_ala__L_e
# phenol_c
# tchola_c
# gly_asn__L_e
# gly_asn__L_c
# MNXM10446_c
# mql8_e
# mqn8_e
# CPD-9151_c
# ocdca_e
# S-PRENYL-L-CYSTEINE_c
# PRENAL_c
# MNXM10217_c
# MNXM6879_c
# MNXM8219_c
# 56dthm_c
# 3uib_c
# MNXM6920_c
# MNXM162552_c
# 34dhoxpeg_c
# 34dhmald_c
# CPD-12646_c
# CPD-17188_c
# MNXM5827_c
# MNXM8894_c
# protdt_c
# protds_c
# CPD-13401_e
# man1p_c
# Ncbmpts_c
# MNXM6176_c
# MNXM6608_c
# adphep_DD_c
# CPD-8678_c
# CPD-8682_c
# glcur_c
# fruur_c
# MNXM7961_c
# sql_c
# D-3-HYDROXYACYL-COA_c
# CPD-472_c
# CPD-13777_c
# 5-UREIDO-4-IMIDAZOLE_CARBOXYLATE_c
# 4-AMINO-5-IMIDAZOLE_CARBOXYLATE_c
# MNXM9653_c
# CPD-586_c
# pta_c
# thm_e
# MNXM9685_c
# MNXM9683_c
# lgt__S_c
# 5aprbu_c
# S-Alkyl-L-Cysteine-S-Oxides_c
# 2amac_c
# Alkyl-Sulfenates_c
# 3oxoadp_c
# CPD-10823_c
# CPD-10824_c
# MNXM5797_c
# MNXM8777_c
# Linalools_c
# MNXM6771_c
# MNXM6766_c
# MNXM146499_c
# MNXM162298_c
# 2-hydroxyacyl-glutathiones_c
# 2-Hydroxy-carboxylates_c
# HOMO-CIT_c
# inost_e
# MNXM2902_c
# CPD-463_c
# MNXM8023_c
# gal_bD_c
# cpd06227_c
# malthp_c
# co2_e
# MNXM8006_c
# 5forthf_c
# D-PROLINE_c
# MNXM146746_c
# 3dsphgn_c
# 2hb_c
# Aryl-Dialkyl-Phosphate_c
# Dialkyl-phosphates_c
# mnt_c
# mn2_c
# BIOMASS_c
# colipa_c
# ca2_c
# kdolipid4_c
# MNXM8210_c
# MNXM8176_c
# cl_e
# MNXM8220_c
# alaala_c
# MNXM92389_c
# gicolipa_c
# ggagicolipa_c
# gggagicolipa_c
# MNXM8149_c
# MNXM8024_c
# gmhep7p_c
# MNXM8015_c
# gagicolipa_c
# phhlipa_c
# hphhlipa_c
# phphhlipa_c
# MNXM8197_c
# MNXM8027_c
# ca2_e
# MNXM8011_c
# MNXM8019_c
# MNXM8004_c
# kphphhlipa_c
# MNXM8226_c
# mn2_e

# %%
count = 0
for met in model_new.metabolites:
    if "bigg.metabolite"  in met.annotation.keys():
        if type(met.annotation["bigg.metabolite"]) == list:
            count+=1

# %%
len(model_new.metabolites)
with_bigg
count

# %%
for reac in model_new.reactions:
    reac.id=reac.id[:-1]
    print(reac.id)

# %% [markdown]
# ### Save draft with mapped Bigg IDs

# %%
#sswrite_sbml_model(model_new, "/Users/lizrad/Documents/Vibrio_folder/iVnat_newbigg.xml")
