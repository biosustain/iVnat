# %%
from pandas import read_csv, DataFrame
import pandas as pd
import os
import re #Both patterns and strings to be searched can be Unicode strings as well as 8-bit strings.
import math
import cobra
import cobra.test
from __future__ import print_function
from os.path import join
from cobra.io import write_sbml_model

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
data_dir = "/Users/lizrad/Dev/iVnat"
print("files found: ")
print(", ".join(i for i in os.listdir(data_dir) if i.startswith("iVnat")))
model=cobra.io.read_sbml_model(join(data_dir, "iVnat.xml"))
#model=cobra.io.read_legacy_sbml("C:\\Users\Asus\Documents\Vibrio_project_literature\GCF_001456255.1_rast_metabolic_model.SBML\GCF_001456255.1_rast_metabolic_model.xml")
model
# Out:
# files found:
# iVnat.json, iVnat.xml, iVnat_newbigg.json
# <Model GCF_001456255_1_rast_metabolic_model at 0x10a708208>

# %%
#skip
#data_dir = "/Users/lizrad/Dev/iVnat"
#print("files found: ")
#print(", ".join(i for i in os.listdir(data_dir) if i.startswith("iVnat")))
#model=cobra.io.read_sbml_model(join(data_dir, "iVnat_mapped.xml"))
#model=cobra.io.read_legacy_sbml("C:\\Users\Asus\Documents\Vibrio_project_literature\GCF_001456255.1_rast_metabolic_model.SBML\GCF_001456255.1_rast_metabolic_model.xml")
#model

# %% [markdown]
# ### Reading the reac_xref

# %%
reac_xref = read_csv("/Users/lizrad/Documents/Vibrio_folder/reac_xref.tsv" , sep='\t')
reac_xref

# %% [markdown]
# ### Number of MNXR reactions in the model

# %%
print ('This is the total amount of reactions in the model: %i' % (len(model.reactions)))

print ('We focus on mapping those %i reactions in the model that have an MNXR ID' % (len([met for met in model.reactions if met.id.startswith('MNXR') ])))

for met in model.reactions:
    if not met.id.startswith('MNXR'):
        print(met.id)

# %%
bigg_reactions = [rxn for rxn in model.reactions if rxn.id.startswith('MNXR')]

print (len(bigg_reactions))
print (len(model.reactions))

# %%
#skip
rxn_mnx2bigg = []
rxn_nobiggid = []

for rxn in [rxn for rxn in model.reactions if rxn.id.startswith('MNXR')]:
    if 'bigg' in rxn.annotation:
        reaction_id = rxn.annotation['BIGG'][0].split(', ')
        tag_split = rxn.id.split('_')
        rxn.id = str(reaction_id[0]) +'_'+ tag_split[1]
        rxn_mnx2bigg.append(reaction_id)
        cameo_model.repair()
    else:
        rxn_nobiggid.append(rxn)
        
print len(rxn_mnx2bigg)
print len(rxn_nobiggid)

# %% [markdown]
# ### Formatting and creating Bigg MNX dictionary

# %%
df_1 = reac_xref.loc[:,'XREF':'MNX_ID']
groups = df_1.groupby(['MNX_ID','XREF'])
df_1 = groups.apply(lambda x:list(x['XREF_ID']))
df_1 =df_1.unstack('XREF') 
reac_xref_MNX_1_dict = df_1.to_dict('index')
reac_xref_MNX_1_dict

# %%
reac_property_MNX = read_csv("/Users/lizrad/Documents/Vibrio_folder/reac_xref.tsv" , sep='\t')
reac_property_MNX.set_index('MNX_ID',inplace = True)
df_3 = reac_property_MNX.fillna('MISSING')  #Fill NA/NaN values using the specified method
df_3
reac_property_MNX_dict = df_3.to_dict('index')
reac_property_MNX_dict

# %%
#skip
#rxn_ID_not_in_MetaNetX_2 = [rxn for rxn in rxn_nobiggid if rxn.id.startswith('MNXR') and ''.join(re.findall('(MNXR\d*)_',rxn.id)) not in reac_xref_MNX_2_dict.keys()]
#print len(rxn_ID_not_in_MetaNetX_2)

# %%
# Get a mapping from KEGG to the new MNXR IDs, for those reactions that cannot be found in the MNX Database,
# but that have a KEGG ID in their annotation. 
#153644- 170637
df_2 = reac_xref.loc[6:26957,'XREF_ID':'MNX_ID']
df_2 = df_2.set_index(['XREF_ID'])
seed_2_mnx_dict_2 = df_2.to_dict('index')
seed_2_mnx_dict_2

# %%
reac_xref_MNXR_bigg = read_csv("/Users/lizrad/Documents/Vibrio_folder/reac_xref.tsv" , sep='\t', low_memory=False)
df_bigg = reac_xref_MNXR_bigg.loc[4:26955,'XREF':'MNX_ID']
pivoted_bigg = df_bigg.pivot_table(index='XREF',columns='XREF_ID',values='MNX_ID',aggfunc = lambda x: x)
pivoted_bigg=pivoted_bigg.drop(['metanetx'])
pivoted_bigg
reac_xref_MNX_bigg_dict = pivoted_bigg.to_dict('index')
reac_xref_MNX_bigg_dict2 = reac_xref_MNX_bigg_dict['bigg']
reac_xref_MNX_bigg_dict2

# %%
not_in_reac_xref = []
in_reac_xref = []

for met in model.reactions:
    split=met.id.split("_")
    met_clean=split[0]
    print(met_clean)
    if not met_clean == '':
        
        if not met_clean in reac_xref_MNX_bigg_dict2.keys():
            not_in_reac_xref.append(met)
        else:
            in_reac_xref.append(met)

print ('%i metabolites with MNXR ID cannot be found in the MNX database' % (len(not_in_reac_xref)))
in_reac_xref

# %% [markdown]
# ### Bigg Ids to reaction annotation

# %%
for reac in model.reactions:
    reac.annotation

# %%
for reac in model.reactions:
    data=''
    if 'metanetx.reaction' in reac.annotation:
        data=reac.annotation['metanetx.reaction'] 
        
        for xref in reac_xref_MNX_bigg_dict2.keys():
            if reac_xref_MNX_bigg_dict2[xref]==data:
                reac.annotation['bigg.reaction']= xref
                print(reac.annotation)

# %% [markdown]
# ### Check for multiple ids

# %%
dupl_bigg = {}
for reac in model.reactions:
    if "bigg.reaction" not in reac.annotation.keys():  #skip EX reactions
        #print(reac.id)
        continue
    if reac.annotation["bigg.reaction"] not in dupl_bigg.keys():
        dupl_bigg.setdefault(reac.annotation["bigg.reaction"],[reac.id]) #similar to get(), but will set dict[key]=default if key is not already in dict.


    else:
        dupl_bigg[reac.annotation["bigg.reaction"]].append(reac.id)
        
dupl_bigg

# %%
for ls in dupl_bigg.values():
    if len(ls) > 1:
        print(ls)

# %%
for ls in dupl_bigg.values():
    if len(ls) > 1:
        print(ls)
        x=[]
        y=[]
        for members in ls: 
            main_id, comp =members.split("_")
            x.append(main_id)
            y.append(comp)
        if not x[0]==x[1]:
            print(x,y)
            for pair in zip(x,y):
                print(len(model.reactions.get_by_id(pair[0]+"_"+pair[1]).reaction))

# %%
for reac in model.reactions:
    
    
    if "bigg.reaction" not in reac.annotation.keys():
        #print(reac.id)
        continue
    if reac.id.startswith('MNXR'):    
        #if reac.id in ["rxn03023_c0"]:
         #   pass
        #else:
        split, compartment=reac.id.split("_")
        reac.id
        reac.id=reac.annotation['bigg.reaction']+ '_' + compartment
        model.repair()
        print(reac.id)

# %%
#chem_xref['#XREF'] = chem_xref['#XREF'].str.replace(':','\t')

#^[0-9A-Za-z]*:[0-9A-Za-z]*
#    (^[0-9A-Za-z]*):([0-9A-Za-z]*)
#        $1 \t $2

# %%
write_sbml_model(model, "/Users/lizrad/Dev/iVnat/iVnat.xml")

# %%
model.reactions.EX_cpd00001_e0.metabolites

# %%
not_in_bigg=[]
for met in model.reactions:
    if "bigg.reaction" not in met.annotation:
        not_in_bigg.append(met.id)
len(not_in_bigg)

# %%
print(len(model.reactions))

# %%
count_reac_more = 0
for reac in model.reactions:
    if "bigg.reaction"  in reac.annotation.keys():
        if type(reac.annotation["bigg.reaction"]) == list:
            print(reac.annotation["bigg.reaction"])
            
            count_reac_more+=1
count_reac_more
# Out:
# ['DHPS2', 'DHPS2_1', 'FOLD3', 'FOLD3_1', 'FOLD3m']
# ['GTHS', 'GTHS_1']
# ['ALCD21_D', 'LCARR']
# ['ADNt2', 'ADNt2pp']
# ['ATPM', 'ATPPHm', 'ATPS', 'NTP1']
# ['SAT', 'SATm', 'SERAT']
# ['CYTK1', 'CYTK1m', 'CYTK1n']
# ['FUMt2r', 'FUMtpp']
# ['GCL', 'GLUCYS']
# ['NDPK7', 'NDPK7m', 'NDPK7n']
# ['PPCK', 'PPCKm']
# ['NO2t2r', 'NO2t2rpp']
# ['PDHam2hi', 'PDHam2mi']
# ['ORNabc', 'ORNabcpp']
# ['MALT', 'MALTe', 'MALTly']
# ['ACONT', 'ACONTm', 'ACONTx']
# ['HACD7', 'HACD7_1', 'HACD7i', 'HACD7m', 'HACD7p']
# ['HYD1', 'HYD1pp']
# ['r0082', 'r0083', 'r0084']
# ['BETALDHx', 'BETALDHxm']
# ['CYTK2', 'CYTK2m', 'CYTK2n']
# ['GLU5K', 'GLU5Km']
# ['ACGS', 'ACGSm']
# ['NTD3', 'NTD3l', 'NTD3pp']
# ['SUCCt2b', 'SUCCt2r', 'SUCCtpp']
# ['MMSAD3', 'MMSAD3m']
# ['AOOA', 'AOOAh', 'HSTPT', 'HSTPTr']
# ['UPPDC2', 'UPPDC2_1']
# ['DMPPS_syn', 'IDS2']
# ['ASPO1', 'ASPOm']
# ['FRTT', 'GGPS_1']
# ['3HAD80', '3HAD80_1']
# ['ORNTAC', 'ORNTAC_1', 'ORNTACim']
# ['LACZ', 'LACZe', 'LACZly', 'LACZpp']
# ['QULNS', 'QULNS_1']
# ['SERD_L', 'SER_AL', 'THRAL']
# ['IDPh', 'IDPm', 'PPA', 'PPA_1', 'PPA_1pp', 'PPAer', 'PPAm', 'PPAn', 'r0009']
# ['DURIt2', 'DURIt2pp']
# ['MMSAD1', 'MMSAD1m']
# ['ORDCh', 'ORNDC']
# ['MTHFO_nadp', 'MTHFR3', 'MTHFR3_1']
# ['SALCpts', 'SALCptspp']
# ['G3PL', 'TRPS3']
# ['GCCc', 'GCCcm']
# ['ASPK', 'ASPK_1']
# ['LCYSTCBOXL', 'SALADC2']
# ['PRONA1tm', 'PROt4', 'PROt4pp']
# ['APNn', 'PDE1', 'PDE1g']
# ['HISDr', 'HISNH4L']
# ['URAOX', 'URO']
# ['AHSERL4', 'CYSS_trdrd']
# ['ACOAD10m', 'ACOADH1']
# ['GPDDA4', 'GPDDA4pp']
# ['IPPS', 'IPPSh', 'IPPSm']
# ['CYSS', 'CYSS_1', 'CYSS_2']
# ['SHKK', 'SKK']
# ['PPND', 'PPOR_1']
# ['AASPh', 'AASPm', 'ADSK', 'ADSKn']
# ['INSt2', 'INSt2pp']
# ['GALCTD', 'GALCTD_1']
# ['HMBS', 'PPBNGD']
# ['ACKr', 'ACKrh', 'ACKrm']
# ['PYK', 'PYKf', 'PYKm']
# ['GLYCK', 'GLYPT', 'r0340']
# ['GAMpts', 'GAMptspp']
# ['DPCOAK', 'DPCOAKm']
# ['G5SADrm', 'G5SADs']
# ['FRUpts', 'FRUptspp']
# ['GAPD', 'GAPDHf', 'GAPDHh', 'GAPDHi', 'GAPDHm']
# ['EX_h2o_e', 'EX_oh1_e', 'H2Ot', 'H2Oter', 'H2Otex', 'H2Otf', 'H2Otg', 'H2Oth', 'H2Othu', 'H2Otly', 'H2Otm', 'H2Otn', 'H2Otn_1', 'H2Otp', 'H2Otpp', 'H2Ots', 'H2Otu_syn', 'H2Otv']
# ['GLUNA1th', 'GLUNA1tm', 'GLUt4', 'GLUt4pp']
# ['SUCCt2_3', 'SUCCt2_3pp']
# ['UPP3S', 'UPP3S_1']
# ['UDPGP', 'UDPGPpp', 'r0093']
# ['CYTDt2', 'CYTDt2pp']
# ['HACD1', 'HACD1_1', 'HACD1_2', 'HACD1i', 'HACD1m', 'HACD1x', 'HBCOm']
# ['ADK1', 'ADK1m', 'ATAMh']
# ['DHQS', 'DHQS_1']
# ['GLGC', 'GLPThi']
# ['CUabcpp', 'Cuabc']
# ['GHMT', 'GHMT2r', 'GHMT2rm']
# ['HISTP', 'HP', 'HPh']
# ['GMP5N', 'NTD9', 'NTD9e', 'NTD9l', 'NTD9pp']
# ['ACALD', 'ACALDh']
# ['DXPRIi', 'DXRI']
# ['ACACT1', 'ACACT1m', 'ACACT1r', 'ACACT1x', 'KAT1']
# ['THD2', 'THD2pp']
# ['LEUabc', 'LEUabcpp']
# ['THMDt2', 'THMDt2pp']
# ['ALDD2x', 'ALDD2xm']
# ['HACD9', 'HACD9m']
# ['ANS', 'ATNS']
# ['MNLpts', 'MNLptspp']
# ['LEUt2r', 'LEUt2rpp', 'LEUt7', 'LEUth', 'LEUtm']
# ['PGPP161', 'PGPP161pp']
# ['PEPCK_re', 'PEPCKm']
# ['NTD8', 'NTD8l', 'NTD8pp']
# ['G3PD2', 'G3PD2_1', 'G3PD2_2']
# ['CGLYabcpp', 'DIPEPabc15']
# ['PRUK', 'PRUK_1']
# ['HPPPNDO', 'HPPPNDO_1']
# ['NH4t', 'NH4tex', 'NH4ti', 'NH4tm', 'NH4tn', 'NH4tp', 'NH4tpp']
# ['ARGDI', 'ARGDr']
# ['DHRT_ibcoa', 'RE3326M']
# ['ARGORNt7', 'ARGORNt7pp', 'ORNtm']
# ['SARCOX', 'SARCOXp']
# ['SHSL2', 'SHSL2h', 'SHSL2r']
# ['3HAD140', '3HAD140_1']
# ['MCITS', 'MCITSm']
# ['GPDDA1', 'GPDDA1pp']
# ['AGTi', 'AGTim', 'AGTix']
# ['FE2abc', 'FE2abcpp']
# ['ALLTAHr', 'ATAH']
# ['MALTpts', 'MALTptspp']
# ['ECOAH4', 'ECOAH4_1', 'ECOAH4m', 'ECOAH4p']
# ['MTHFD', 'MTHFD_1', 'MTHFDm', 'MTHFDm_1']
# ['ECOAH5', 'ECOAH5_1', 'ECOAH5_2', 'ECOAH5m', 'ECOAH5p']
# ['STS1', 'STS1r']
# ['HOXPRm', 'HOXPRx', 'TRSARr']
# ['GLYCt', 'GLYCt1', 'GLYCtex', 'GLYCtm', 'GLYCtpp']
# ['PROD2', 'PROD2m']
# ['XAND', 'XANDp']
# ['ICL', 'ICL_1']
# ['DHORTS', 'DHORTSn', 'DHR']
# ['MHPGLUT', 'MS', 'MTHPTGHMr']
# ['PIabc', 'PIuabcpp']
# ['AKGDHe2r', 'AKGDb', 'AKGDbm', 'r0556']
# ['HSDx', 'HSDxi']
# ['ASAD', 'ASADH', 'ASADi']
# ['GDTP', 'GTPDPDP']
# ['MDH', 'MDHf', 'MDHh', 'MDHi2', 'MDHm', 'MDHm_1', 'MDHp', 'MDHx']
# ['LDH_L', 'LDH_Lm', 'LLDHh', 'r0173']
# ['GLUTRS', 'GLUTRS_1', 'GLUTRSm']
# ['ACOTA', 'ACOTAim', 'AOTA']
# ['CYSDS', 'CYSTBL', 'TRPAS1']
# ['NTD2', 'NTD2e', 'NTD2l', 'NTD2m', 'NTD2pp']
# ['MCITL2', 'MCITL2m']
# ['RBFK', 'RBFKm']
# ['TPI', 'TPIh']
# ['FBA3', 'FBA3hi']
# ['IDIh', 'IPDDI', 'IPDDIx']
# ['METabc', 'METabcpp']
# ['PPBNGS', 'PPBNGS_1']
# ['HACD6', 'HACD6_1', 'HACD6i', 'HACD6m', 'HACD6p']
# ['APPAT', 'PTPATe', 'PTPATi', 'PTPATim']
# ['DADNt2', 'DADNt2pp']
# ['PRACHh', 'PRAMPC', 'PRAMPC_1']
# ['GLYCLTDy', 'GLYCLTDym']
# ['BCTA', 'BCTAh', 'ILETA', 'ILETAm']
# ['ZNabc', 'ZNabcpp']
# ['ECOAH7', 'ECOAH7_1', 'ECOAH7m', 'ECOAH7p']
# ['DLDLBT', 'RBFSa']
# ['TAL', 'THRD_L', 'THRD_Lm']
# ['5CM2HMUDI', 'CMHMI']
# ['URIt2', 'URIt2pp']
# ['HDCAt2', 'HDCAt2pp']
# ['G1SAT', 'G1SAT_1']
# ['HISabc', 'HISabcpp']
# ['SHK3Dr', 'SKDH']
# ['DNGALh', 'NADS2']
# ['DCYTt2', 'DCYTt2pp']
# ['GLYCOR_nadp', 'HPYRRy']
# ['23CN2P3', '23PDE4pp']
# ['PCNO', 'PCNOn']
# ['SUCpts', 'SUCptspp']
# ['ILEt2r', 'ILEt2rpp', 'ILEt7', 'ILEth', 'ILEtm']
# ['P5CD', 'P5CDm']
# ['ADPT', 'r0051']
# ['GCPN', 'GCPNn', 'PDE4', 'PDE4g']
# ['GLUPRT', 'PRDPARh']
# ['MCS', 'MECDPS']
# ['ATGDm', 'NDPK1', 'NDPK1m', 'NDPK1n']
# ['SPTc', 'SPTix']
# ['PRICIh', 'PRMICI']
# ['3OAR160', '3OAR160_1']
# ['ACPpds', 'r0366']
# ['SUCLm', 'SUCOAS', 'SUCOASm']
# ['OBTFL', 'PCFPTh', 'PCFPTm']
# ['LIPATPT', 'RE1944C']
# ['GDH', 'GDH1', 'GDHm', 'GLUDxi']
# ['CYANST', 'CYANSTm', 'CYANSTpp']
# ['GALTpts', 'GALTptspp']
# ['HPHL', 'HPHLm', 'PRPNCOAHYDm', 'PRPNCOAHYDx']
# ['TAURabc', 'TAURabcpp']
# ['IZPN', 'IZPN_1']
# ['NTD7', 'NTD7e', 'NTD7l', 'NTD7pp', 'r0047']
# ['ABTA', 'ABTArm']
# ['MATm', 'METAT']
# ['DURIK1', 'DURIK1m']
# ['HPI', 'HPYRI']
# ['SPMDabc', 'SPMDabcpp']
# ['MINOHPKn', 'PMI12346PS']
# ['PDHbr', 'PDHe2hr', 'PDHe2r', 'r0555']
# ['3OAR120', '3OAR120_1']
# ['ARGDC', 'ARGDCm', 'ARGDCpp']
# ['SERt2m', 'SERt2r', 'SERt2rpp', 'SERth']
# ['GTPCI', 'GTPCI_1', 'GTPCI_2', 'GTPCIn']
# ['PI34P4P', 'PI34P4Pn_cho']
# ['PNTOt4', 'PNTOt4pp']
# ['ALDD31', 'ALDD31_1']
# ['AOXHEXCYCL', 'PPD2CSPp']
# ['NTD4', 'NTD4e', 'NTD4l', 'NTD4pp']
# ['NMNHYD', 'NMNR']
# ['23CN2P2', '23PDE2pp', 'RE1860E']
# ['METDabc', 'METDabcpp']
# ['HSK', 'HSK_1']
# ['CDPMEK', 'CMK']
# ['SHSL4h', 'SHSL4r']
# ['PGK', 'PGK_1', 'PGKf', 'PGKh', 'PGKm']
# ['ADSS', 'ADSSh']
# ['H2CO3D', 'H2CO3Dm', 'HCO3E', 'HCO3E_1', 'HCO3Ee', 'HCO3Ehi', 'HCO3Em', 'HCO3Em_1', 'HCO3En']
# ['GLYCLTDx', 'GLYCTO_syn']
# ['NTD11', 'NTD11pp']
# ['CHORS', 'CHRS']
# ['ASPt2_3', 'ASPt2_3pp']
# ['ACGApts', 'ACGAptspp']
# ['HKNDDH', 'HKNDDH_1']
# ['MTHFC', 'MTHFC_1', 'MTHFCm', 'MTHFCm_1', 'MTHFCx']
# ['ALAt2pp', 'ALAt2r', 'ALAt2rL', 'ALAtm', 'ALAtx']
# ['TYRTA', 'TYRTAh', 'TYRTAi', 'TYRTAim', 'TYRTAip', 'TYRTAm', 'TYRTAp']
# ['AP4AH', 'BTPS']
# ['LYSabc', 'LYSabcpp']
# ['ACGK', 'ACGKm']
# ['ARBTpts', 'ARBTptspp']
# ['PTAr', 'PTArh', 'PTArm']
# ['PUNP3', 'PUNP3m']
# ['NTD5', 'NTD5l', 'NTD5m', 'NTD5pp']
# ['DGSNt2', 'DGSNt2pp']
# ['PTRCabc', 'PTRCabcpp']
# ['XANt2', 'XANt2pp']
# ['PGPP180', 'PGPP180pp']
# ['GALh', 'GALm', 'GLNS']
# ['LDH_D', 'LDHm']
# ['ALLTNt2r', 'ALLTNt2rpp']
# ['CAT', 'CATm', 'CATp']
# ['3OAR100', '3OAR100_1']
# ['IG3PS', 'IG3PS_1', 'IMGPSh']
# ['SBP', 'SBP_1']
# ['GPAR', 'GUAPRT']
# ['OXADC', 'OXADCm']
# ['ALDD20x_1', 'IMACTD', 'IMACTD_m']
# ['3OAR60', '3OAR60_1']
# ['PPPNt2r', 'PPPNt2rpp']
# ['FTCL', 'FTHFCL', 'FTHFCLm']
# ['TRPS2', 'TRPS2h']
# ['PRAISh', 'PRASCSi']
# ['DINSt2', 'DINSt2pp']
# ['RPE', 'RPEh']
# ['IMDHT_3c2hmp', 'IPPMIa']
# ['DPMVD', 'DPMVDx']
# ['ACOAD1', 'BCOR']
# ['MALTTRabc', 'MALTTRabcpp']
# ['PCPPTh', 'PCPPTm', 'PTA2']
# ['UPPRT', 'UPRT']
# ['SBTpts', 'SBTptspp']
# ['GLYCL', 'GLYCL_2', 'GLYCLm', 'GLYS']
# ['PUNP1', 'PUNP1m']
# ['NNDPR', 'NNDPRm']
# ['MEVK1', 'MEVK1x']
# ['MCOATA', 'MCOATA_1', 'MCOATAm']
# ['DALAt2pp', 'DALAt2r', 'DALAt2rL']
# ['KAS14', 'KAS14_1']
# ['METSOXR1', 'METSOXR2', 'METSR_S1']
# ['ALCD4', 'BTS']
# ['FBA2', 'FPGPL']
# ['ACPS1', 'ACPS1_1', 'ACPS1h', 'r0368']
# ['G3PD1', 'G3PD1_1', 'G3PD1ir', 'G3PD1irm', 'r0202']
# ['NDPK6', 'NDPK6m', 'NDPK6n']
# ['ARGN', 'ARGN_1', 'ARGNm']
# ['ACOA40OR', 'ACOAD1f', 'ACOAD1fm']
# ['ICH', 'IMPC']
# ['PGM', 'PGM_1', 'PGMf', 'PGMm']
# ['FTHFLi', 'FTHFLmi']
# ['P5CR', 'P5CRm', 'PRO1y']
# ['NNAM', 'NNAMrm']
# ['AMPTASECG', 'AMPTASECGe']
# ['AKP1', 'AKP1_1', 'r0707']
# ['ASPabc', 'ASPabcpp']
# ['ACPh', 'ACYP']
# ['HKNTDH', 'HKNTDH_1']
# ['NDPK9', 'NDPK9m', 'NDPK9n']
# ['FGFTh', 'FGFTm']
# ['ATDGDm', 'NDPK5', 'NDPK5m', 'NDPK5n']
# ['HACD4', 'HACD4_1', 'HACD4i', 'HACD4m', 'HACD4p']
# ['G3PD', 'G3PDm']
# ['G6PDA', 'G6PDA_1']
# ['FGLU', 'FGLU_1']
# ['ECOAH12', 'ECOAH12m']
# ['ACACT4m', 'ACACT4p', 'ACACT4r', 'KAT4']
# ['MG2abc', 'MG2uabcpp']
# ['LNSTLS', 'LNSTLSr']
# ['MANpts', 'MANptspp']
# ['ATPS4m', 'ATPS4m_cho', 'ATPS4r', 'ATPS4rpp', 'ATPSh', 'ATPasel']
# ['LCADi', 'LCADm']
# ['PPRGL', 'PPRGLh', 'PRAGSr']
# ['ECOAH9ir', 'ECOAH9m']
# ['GAM', 'GLUN', 'GLUNm', 'GLUNpp']
# ['PRAI', 'PRAIi']
# ['ALCD2ir', 'ALCD2irm', 'ALCD2m', 'ALCD2x']
# ['6PHBG', 'S6PG']
# ['PSP', 'PSP_L', 'PSP_Lpp']
# ['ACODA', 'ACODA_1']
# ['ACACT7m', 'ACACT7p', 'ACACT7r', 'KAT7', 'r0653']
# ['RBFSb', 'RIBFS']
# ['RNDR1', 'RNDR1n']
# ['ANS2', 'ATNS_nh4']
# ['SADT', 'SADTn']
# ['3HAD60', '3HAD60_1']
# ['NNATm', 'NNATn', 'NNATr']
# ['ACOAD8m', 'MBCOAi']
# ['MALTabc', 'MALTabcpp']
# ['SUCR', 'SUCRe']
# ['ASPCT', 'ASPCT_1', 'ASPCTm', 'ASPCTn']
# ['GSNK', 'GSNKm']
# ['L_LACt2r', 'L_LACt2rpp', 'L_LACtm', 'r2516']
# ['FACOAL160', 'FACOAL160p', 'r0311']
# ['ECOAH3', 'ECOAH3_1', 'ECOAH3m']
# ['ALAD_L', 'ALAD_syn']
# ['PGL', 'PGLer', 'PGLh']
# ['GTHPe', 'GTHPe_1', 'GTHPi', 'GTHPm']
# ['IMDHT', 'IPPMIb']
# ['AACOAT', 'r0321']
# ['DHRT_ivcoa', 'r0656']
# ['PNTK', 'PNTKm']
# ['3OAR140', '3OAR140_1']
# ['GLUabc', 'GLUabcpp']
# ['CBPS', 'CBPSn', 'HCGALm']
# ['ME1', 'ME1m']
# ['ACOATA', 'ACOATA_1', 'ACOATAm']
# ['GTPDPK', 'GTPDPK_1']
# ['FUM', 'FUMm']
# ['GPDDA2', 'GPDDA2pp']
# ['PDHam1hi', 'PDHam1mi']
# ['THRS', 'THRS_1']
# ['CU2abcpp', 'CU2abcu_syn', 'Cut1']
# ['ANPRT', 'ANTPPT']
# ['ADECn', 'ADNCYC']
# ['CYTDK1', 'CYTDK2m']
# ['GLYBabc', 'GLYBabcpp']
# ['PIt2m', 'PIt2n', 'PIt2p', 'PIt2r', 'PIt2rpp', 'PIt2v', 'PItf']
# ['NADH5', 'NADHOR']
# ['ANNAT', 'ANNATn', 'NMNAT', 'NMNATm', 'NMNATn']
# ['HSDH', 'HSDy', 'HSDyi']
# ['PNTEH', 'PNTEHe']
# ['XYLI2', 'XYLI2i']
# ['ALANA1tm', 'ALANA1tx', 'ALAt4', 'ALAt4pp']
# ['DHCINDO', 'DHCINDO_1']
# ['DDPGA', 'DDPGAm']
# ['SDPTA', 'SDPTAi']
# ['ACYP_2', 'APhi']
# ['APCPT', 'r0679', 'r0680']
# ['MCCC', 'MCCCrm', 'MCTC']
# ['TRPt2m', 'TRPt2r', 'TRPt2rpp', 'TRPth']
# ['FORt2', 'FORt2pp', 'FORthi', 'FORti_1', 'FORtmi', 'FORtxi']
# ['CMS', 'MEPCT']
# ['PRADPh', 'PRATPP']
# ['DMATT', 'DMATTx', 'GPPSh']
# ['ENO', 'ENOf', 'ENOm']
# ['URCN', 'URCN_1', 'UROCANH']
# ['SULabc', 'SULabcpp']
# ['FE3abc', 'FE3abcpp']
# ['NA1Hth', 'NA1Htm', 'NAt3_1', 'NAt3_1g', 'NAt3pp']
# ['GCCa', 'GCCam', 'GLYDHD']
# ['ACS', 'ACSm', 'ACSp']
# ['PRDX', 'PRDXl']
# ['NO3R2', 'NO3R2pp']
# ['OMCDC', 'OMCDCm']
# ['PROabc', 'PROabcpp']
# ['TMDK1', 'TMDK1m']
# ['COBALT2tex', 'COBALT2tpp', 'COBALTt5']
# ['ASPATh', 'ASPTA', 'ASPTAm', 'ASPTAp']
# ['NO3R1', 'NO3R1pp']
# ['METSOX1abcpp', 'METSOX2abcpp', 'METSabc']
# ['DGGH', 'GALS3', 'MGHB']
# ['AGMT', 'AGMTm']
# ['r0422', 'r0423', 'r0424']
# ['RAFGH', 'RGH']
# ['HOPNTAL', 'HOPNTAL3']
# ['FOMETRi', 'MTAM', 'THFAT', 'THFATm']
# ['GGTAe2', 'GTHRDH_syn', 'GTHRDHpp']
# ['GND', 'GNDer', 'PGDHh']
# ['BDH', 'BDHm', 'HBNOx']
# ['AHHST', 'AHSERL2']
# ['MDHC_nadp_hr', 'ME2', 'ME2m']
# ['NTD10', 'NTD10pp']
# ['URIDK2m', 'URIDK2r', 'URIDK2rn']
# ['ALDD19xr', 'r0546']
# ['3HAD120', '3HAD120_1']
# ['DCYTD', 'DCYTDn']
# ['PSCIT', 'PSCVT']
# ['NDPK4', 'NDPK4m', 'NDPK4n']
# ['HDC', 'HISDC']
# ['MTHFO', 'MTHFR2', 'MTHFR2_1', 'r0792']
# ['HACD2', 'HACD2_1', 'HACD2i', 'HACD2m']
# ['IDS1', 'IPDPS_syn']
# ['ACACT10m', 'MACCOAT']
# ['ETHAt2pp', 'ETHAt6']
# ['FRD7', 'SUCDH_q8_m', 'SUCDi']
# ['BCTA_val_h', 'BCTA_val_m', 'VALTA', 'VALTAim']
# ['PGLYCP', 'PGLYCPh', 'PGLYCPx']
# ['FERO', 'FEROc', 'FEROpp', 'r0016']
# ['DHQTi', 'DQDH']
# ['PPTT', 'PPTTm']
# ['GDR_nadp_h', 'GTHOm', 'GTHOr']
# ['ATDAMh', 'ATDAMm', 'DADK']
# ['GLCpts', 'GLCptspp']
# ['GLYK', 'GLYKm']
# ['23CN2P1', '23PDE7pp']
# ['3OAR80', '3OAR80_1']
# ['NADTRHD', 'NNOR']
# ['DHPD', 'DHPM1']
# ['ALKP', 'r0242']
# ['23CN2P4', '23PDE9pp']
# ['NAPRT', 'NAPRTm', 'NCTPPRT']
# ['ACACT2', 'ACACT2m', 'ACACT2r', 'KAT2']
# ['IMPD', 'IMPDm']
# ['GAPDH_nadp_hi', 'GAPD_nadp', 'GAPDi_nadp']
# ['4ABUTD', 'ABOR']
# ['NO3t2', 'NO3t2pp']
# ['PIt7', 'PIt7ipp']
# ['ARGabc', 'ARGabcpp']
# ['DDPA', 'DDPAm', 'DPHS']
# ['RDH1', 'TRETINOLOR1']
# ['METS', 'METS_1', 'METSm']
# ['DXPS', 'DXS']
# ['CYTBD2', 'CYTBD2pp']
# ['PGCD', 'PGLYDH']
# ['GCCb', 'GCCbim', 'MTAM_nh4']
# ['TREpts', 'TREptspp']
# ['GLUt2m', 'GLUt2n', 'GLUt2r', 'GLUt2rpp', 'GLUt7', 'GLUth']
# ['ARGDh', 'GLUDC']
# ['BCTA_glu_h', 'LEUTA', 'LEUTAi', 'LEUTAm']
# ['RIBabc', 'RIBabcpp']
# ['ABUTD', 'ABUTDm']
# ['HXANt2pp', 'HXANt2r']
# ['MG2t', 'MG2tex', 'MG2th', 'MG2tpp', 'MG2tu', 'MGt5']
# ['NTD6', 'NTD6l', 'NTD6pp']
# ['DPR', 'DPRm', 'PNORm', 'PNORn']
# ['SO4t2', 'SO4t2pp']
# ['NADK', 'NADKm']
# ['SHCHF', 'SHCHF_1', 'SHCHF_2']
# ['R01465m', 'THRD']
# ['GALS4', 'STACHGALACT', 'SYGH']
# ['HACD5', 'HACD5_1', 'HACD5i', 'HACD5m', 'HACD5p']
# ['THRA', 'THRA_1', 'THRAi']
# ['CYTD', 'CYTDn']
# ['ADNK1', 'ADNK1m', 'ADNK1n']
# ['RNDR2', 'RNDR2n']
# ['ADSHm', 'AHCi']
# ['TDPDRR', 'TDPDRRr']
# ['GCC2cm', 'PDHcr', 'PDHe3hr']
# ['HDH', 'HDHh', 'HISTD']
# ['3HAD160', '3HAD160_1']
# ['FRD', 'FRDm', 'SUCD1', 'SUCD1m', 'SUCDHh']
# ['IGPDH', 'IGPDH_1', 'IGPDh']
# ['GNK', 'GNKh', 'GNKr']
# ['MALTHXabc', 'MALTHXabcpp']
# ['ARGSS', 'ARGSS_1']
# ['MOHMT', 'MTMOHT']
# ['AFAT', 'FMNAT', 'FMNATm']
# ['RNDR3', 'RNDR3n']
# ['GLYCDH_1', 'HPYRRx']
# ['CYNTt2', 'CYNTt2pp']
# ['TYRt2m', 'TYRt2p', 'TYRt2r', 'TYRt2rpp', 'TYRt7', 'TYRth']
# ['ILEabc', 'ILEabcpp']
# ['DHFOR2', 'FOLR2', 'FOLR2_1', 'r0514']
# ['AKGDH', 'AKGDm']
# ['ECOAH6', 'ECOAH6_1', 'ECOAH6m', 'ECOAH6p']
# ['NTD1', 'NTD1m', 'NTD1pp']
# ['KHte', 'Kt3g', 'Kt3pp', 'Kt3r']
# ['ASPO6', 'ASPO6_1']
# ['G6PBDH', 'G6PBDHh']
# ['G5DHx', 'G5SD', 'G5SDym']
# ['OP4ENH', 'OP4ENH3']
# ['GLUS_nadph', 'GLUSy']
# ['RAFH', 'RAFHpp']
# ['UMPK', 'UMPKm', 'UMPKn']
# ['HIUH', 'HURH']
# ['O2t', 'O2ter', 'O2tex', 'O2thr', 'O2tm', 'O2tn', 'O2tp', 'O2tpp', 'O2trhu', 'O2tu']
# ['FPPSh', 'GRTT', 'GRTTx']
# ['CHLt2', 'CHLt2pp']
# ['GUAD', 'GUAD_1']
# ['INSK', 'INSKm']
# ['UPPDC1', 'UPPDC1_1']
# ['NDPK3', 'NDPK3m', 'NDPK3n']
# ['VALt2m', 'VALt2r', 'VALt2rpp', 'VALth']
# ['APNPT', 'r0579']
# ['GALKh', 'GALKr']
# ['NDPK10', 'NDPK10m', 'NDPK10n']
# ['URAt2', 'URAt2pp']
# ['P5CRx', 'P5CRxm', 'PRO1x', 'PRO1xm']
# ['CS', 'CSm', 'CSp']
# ['FPGFTh', 'FPGFTm', 'GARFT']
# ['NADS1', 'NADS1m', 'NADS1n']
# ['VALabc', 'VALabcpp']
# ['ECOAH1', 'ECOAH1_1', 'ECOAH1_2', 'ECOAH1m', 'ECOAH1x']
# ['DADA', 'DADAe']
# ['TMAOR1e', 'TMAOR1pp']
# ['OCDCAt2', 'OCDCAt2pp']
# ['PGAMT', 'PGAMTi']
# ['PGPP160', 'PGPP160pp']
# ['Kt1', 'Ktex', 'r1492']
# ['THIORDXi', 'THIORDXm', 'THIORDXni', 'THIORDXp']
# ['GK1', 'GK1m']
# ['AGGPR', 'AGPR', 'AGPRim']
# ['PANTS', 'PBAL', 'PBALm']
# ['PUTA3', 'r0074']
# ['SULR', 'SULR_1', 'SULRi']
# ['MPPM', 'PMANM']
# ['ALPHNH', 'ALPHm']
# ['IGPS', 'IGPS_1']
# ['AGDI', 'AGDIn', 'AGMDA']
# ['SERH', 'TRPS1']
# ['PPCDC', 'r0614']
# ['GLUTRR', 'GLUTRR_1']
# ['DUTPDP', 'DUTPDPm', 'DUTPDPn']
# ['ADA', 'ADAe']
# ['SMO', 'SQLEr']
# ['DTMPK', 'DTMPKm']
# ['3HAD100', '3HAD100_1']
# ['ACACT6m', 'ACACT6p', 'ACACT6r', 'KAT6']
# ['THMabc', 'THMabcpp']
# ['GLYOX', 'GLYOXm']
# ['APRAUR', 'AUNOR']
# ['HACD3', 'HACD3_1', 'HACD3i', 'HACD3m']
# ['G6PDH2er', 'G6PDH2r']
# ['GLYAT', 'GLYATi', 'GLYATm', 'GLYATx']
# ['OCBT', 'OCBT_1', 'OCBTm', 'OCT', 'OCTh', 'OCTm']
# ['LYSt3pp', 'LYSt3r', 'LYSt6', 'LYStm']
# ['INOSTtpp', 'INSTt2']
# ['PSAT', 'PSERT']
# ['DHFS', 'DHFS_1']
# ['DHFR', 'DHFRim']
# ['PFL', 'PFLACTm', 'PFLh']
# ['RNDR4', 'RNDR4n']
# ['GLYALDDr', 'GLYALDOR', 'r0393']
# ['TDSRh', 'TRDR', 'TRDRm']
# ['CO2t', 'CO2ter', 'CO2tex', 'CO2tg', 'CO2th', 'CO2tm', 'CO2tn', 'CO2tp', 'CO2tpp', 'CO2tpp_1', 'CO2tv']
# ['NDPK2', 'NDPK2m', 'NDPK2n']
# ['MALS', 'MALSh', 'MALSm', 'MALSp']
# ['GLUFORT', 'GluForTx']
# ['PHETA1', 'PHETA1m', 'POAT', 'POATh', 'POATm']
# ['GLYOX_1', 'LGTHL']
# ['2HBO', 'LDH2']
# ['NDPK8', 'NDPK8m', 'NDPK8n']
# ['CLtex', 'Clt']
# ['GCALDD', 'GCALDDm']
# ['SHCHD2', 'SHCHD2_1']
# ['CA2t3pp', 'CAt4']
# ['AUS', 'PMDPHT']
# 550

# %% [markdown]
# ### Mapping to bigg IDs using the annotation field

# %%
data_dir = "/Users/lizrad/Documents/Vibrio_folder"
print("files found: ")
print(", ".join(i for i in os.listdir(data_dir) if i.startswith("iVnat")))
model_new=cobra.io.read_sbml_model(join(data_dir, "iVnat_newbigg.xml"))
#model=cobra.io.read_legacy_sbml("C:\\Users\Asus\Documents\Vibrio_project_literature\GCF_001456255.1_rast_metabolic_model.SBML\GCF_001456255.1_rast_metabolic_model.xml")
model_new
# Out:
# files found:
# iVnat_newbigg.xml, iVnatReport.html, iVnat_bigg.xml, iVnat_gapfill_glu.xml, iVnat_20180817.xml
# <Model GCF_001456255_1_rast_metabolic_model at 0x10a37d128>

# %%
with_bigg=0
for reac in model_new.reactions:
    print(reac.id)
    
    if "bigg.reaction" not in reac.annotation.keys():
        continue
    if reac.id.startswith("MNXR") or  reac.id==model_new.reactions.bio1:
        continue
       
    else:
        split, compartment=reac.id.rsplit("_", 1)
        with_bigg+=1
        if type(reac.annotation["bigg.reaction"]) == list:
            print("whole annotation:" ,reac.annotation['bigg.reaction'])
            
            reac.id=reac.annotation['bigg.reaction'][0]+ '_' + compartment
        else: 
            reac.id=reac.annotation['bigg.reaction']+ '_' + compartment
   
    print("new id :",reac.id)
            
    #if reac.id.startswith('cpd'):
    model_new.repair()

       # print(reac.id)

# %%
for reac in model_new.reactions:
    print(reac.id)
    reac.id=reac.id[:-2]
    print(reac.id)
# Out:
# DHPS2_c
# DHPS2
# GTHS_c
# GTHS
# MNXR101695_c
# MNXR101695
# HXPRT_c
# HXPRT
# ALCD21_D_c
# ALCD21_D
# ASPARTOACYLASE-RXN_c
# ASPARTOACYLASE-RXN
# MNXR96343_c
# MNXR96343
# ADNt2_c
# ADNt2
# ATPM_c
# ATPM
# GAMMA-GLUTAMYLCYCLOTRANSFERASE-RXN_c
# GAMMA-GLUTAMYLCYCLOTRANSFERASE-RXN
# MNXR108115_c
# MNXR108115
# SAT_c
# SAT
# CYTK1_c
# CYTK1
# MNXR99713_c
# MNXR99713
# MNXR105037_c
# MNXR105037
# ICHORT_c
# ICHORT
# MNXR134818_c
# MNXR134818
# GCL_c
# GCL
# MNXR97508_c
# MNXR97508
# NDPK7_c
# NDPK7
# PPCK_c
# PPCK
# MNXR101984_c
# MNXR101984
# 4-HYDROXYPROLINE-EPIMERASE-RXN_c
# 4-HYDROXYPROLINE-EPIMERASE-RXN
# MNXR102429_c
# MNXR102429
# MNXR136307_c
# MNXR136307
# ORNabc_c
# ORNabc
# MALT_c
# MALT
# MNXR95384_c
# MNXR95384
# MNXR126081_c
# MNXR126081
# TDPDRE_c
# TDPDRE
# HACD7_c
# HACD7
# FLAVONE-APIOSYLTRANSFERASE-RXN_c
# FLAVONE-APIOSYLTRANSFERASE-RXN
# SS-BUTANEDIOL-DEHYDROGENASE-RXN_c
# SS-BUTANEDIOL-DEHYDROGENASE-RXN
# MNXR136769_c
# MNXR136769
# LYSDC_c
# LYSDC
# ABTDG_c
# ABTDG
# MNXR134793_c
# MNXR134793
# RXN3O-8214_c
# RXN3O-8214
# MNXR106405_c
# MNXR106405
# MNXR110225_c
# MNXR110225
# MNXR137716_c
# MNXR137716
# MNXR100753_c
# MNXR100753
# MNXR134889_c
# MNXR134889
# MNXR109713_c
# MNXR109713
# MNXR97378_c
# MNXR97378
# r0788_c
# r0788
# PDXJ-RXN_c
# PDXJ-RXN
# r0082_c
# r0082
# PUNP5_c
# PUNP5
# MNXR136227_c
# MNXR136227
# SOTA_c
# SOTA
# BETALDHx_c
# BETALDHx
# RXN-9888_c
# RXN-9888
# MNXR136266_c
# MNXR136266
# RXN0-6987_c
# RXN0-6987
# OPHELINE-KINASE-RXN_c
# OPHELINE-KINASE-RXN
# MNXR104241_c
# MNXR104241
# CYTK2_c
# CYTK2
# RHCCE_c
# RHCCE
# RXN-12481_c
# RXN-12481
# MNXR106487_c
# MNXR106487
# ADSL1r_c
# ADSL1r
# MNXR97200_c
# MNXR97200
# PPNCL2_c
# PPNCL2
# UDPGD_c
# UDPGD
# GLU5K_c
# GLU5K
# MNXR107108_c
# MNXR107108
# ANTHRANILATE-N-MALONYLTRANSFERASE-RXN_c
# ANTHRANILATE-N-MALONYLTRANSFERASE-RXN
# ACGS_c
# ACGS
# NTD3_c
# NTD3
# MNXR134864_c
# MNXR134864
# RXN-11050_c
# RXN-11050
# MNXR109210_c
# MNXR109210
# MNXR102012_c
# MNXR102012
# MNXR104622_c
# MNXR104622
# XYLK_c
# XYLK
# MNXR106666_c
# MNXR106666
# MNXR106803_c
# MNXR106803
# FCLK_c
# FCLK
# MNXR135851_c
# MNXR135851
# MNXR101487_c
# MNXR101487
# MMSAD3_c
# MMSAD3
# ACITL_c
# ACITL
# MNXR136339_c
# MNXR136339
# r1384_c
# r1384
# MNXR136332_c
# MNXR136332
# AOOA_c
# AOOA
# UPPDC2_c
# UPPDC2
# N-ACYLGLUCOSAMINE-2-EPIMERASE-RXN_c
# N-ACYLGLUCOSAMINE-2-EPIMERASE-RXN
# 2.5.1.45-RXN_c
# 2.5.1.45-RXN
# DHNPA2r_c
# DHNPA2r
# RBP4E_c
# RBP4E
# MNXR97525_c
# MNXR97525
# MNXR96088_c
# MNXR96088
# MNXR134901_c
# MNXR134901
# CHENODEOXYCHOLOYLTAURINE-HYDROLASE-RXN_c
# CHENODEOXYCHOLOYLTAURINE-HYDROLASE-RXN
# MNXR136258_c
# MNXR136258
# MNXR104630_c
# MNXR104630
# MNXR136206_c
# MNXR136206
# RXN-17022_c
# RXN-17022
# MNXR136221_c
# MNXR136221
# MNXR109325_c
# MNXR109325
# FRTT_c
# FRTT
# MNXR106867_c
# MNXR106867
# 3HAD80_c
# 3HAD80
# MNXR136202_c
# MNXR136202
# MNXR97178_c
# MNXR97178
# MNXR134897_c
# MNXR134897
# ORNTAC_c
# ORNTAC
# MNXR104076_c
# MNXR104076
# CREATININE-DEAMINASE-RXN_c
# CREATININE-DEAMINASE-RXN
# MNXR99880_c
# MNXR99880
# MNXR101000_c
# MNXR101000
# CDPGLC46DH_c
# CDPGLC46DH
# MNXR103400_c
# MNXR103400
# FALDH2_c
# FALDH2
# MTAN_c
# MTAN
# SERD_L_c
# SERD_L
# MNXR136224_c
# MNXR136224
# A5PISO_c
# A5PISO
# DOPACHROME-DELTA-ISOMERASE-RXN_c
# DOPACHROME-DELTA-ISOMERASE-RXN
# MNXR106480_c
# MNXR106480
# MNXR97475_c
# MNXR97475
# ETHAAL_c
# ETHAAL
# MNXR111763_c
# MNXR111763
# MNXR137842_c
# MNXR137842
# 2.1.3.1-RXN_c
# 2.1.3.1-RXN
# IDPh_c
# IDPh
# RXN-11746_c
# RXN-11746
# DURIt2_c
# DURIt2
# E4PD_c
# E4PD
# MNXR97478_c
# MNXR97478
# HYDROXYBENZALDEHYDE-OXIDATION-NADP-RXN_c
# HYDROXYBENZALDEHYDE-OXIDATION-NADP-RXN
# MNXR101662_c
# MNXR101662
# MNXR136581_c
# MNXR136581
# OMPDC_c
# OMPDC
# RBK_Dr_c
# RBK_Dr
# TMPPP_c
# TMPPP
# ORDCh_c
# ORDCh
# MNXR135861_c
# MNXR135861
# MNXR101752_c
# MNXR101752
# MNXR136766_c
# MNXR136766
# MNXR97177_c
# MNXR97177
# MNXR135767_c
# MNXR135767
# MNXR97474_c
# MNXR97474
# CSND_c
# CSND
# MNXR100602_c
# MNXR100602
# MNXR104266_c
# MNXR104266
# HXAND_c
# HXAND
# MNXR136250_c
# MNXR136250
# 23-DIMETHYLMALATE-LYASE-RXN_c
# 23-DIMETHYLMALATE-LYASE-RXN
# MNXR134954_c
# MNXR134954
# MNXR134950_c
# MNXR134950
# G3PL_c
# G3PL
# MNXR135842_c
# MNXR135842
# 5.2.1.10-RXN_c
# 5.2.1.10-RXN
# TDSK_c
# TDSK
# FORMALDEHYDE-TRANSKETOLASE-RXN_c
# FORMALDEHYDE-TRANSKETOLASE-RXN
# KIEVITONE-HYDRATASE-RXN_c
# KIEVITONE-HYDRATASE-RXN
# MNXR100934_c
# MNXR100934
# MNXR100069_c
# MNXR100069
# MNXR136210_c
# MNXR136210
# MNXR100357_c
# MNXR100357
# ASPK_c
# ASPK
# LCYSTCBOXL_c
# LCYSTCBOXL
# PRONA1tm_c
# PRONA1tm
# MNXR97156_c
# MNXR97156
# PYAM5PO_c
# PYAM5PO
# BRANCHED-CHAIN-FATTY-ACID-KINASE-RXN_c
# BRANCHED-CHAIN-FATTY-ACID-KINASE-RXN
# MNXR135865_c
# MNXR135865
# MNXR95765_c
# MNXR95765
# APNn_c
# APNn
# RXN-9516_c
# RXN-9516
# HISDr_c
# HISDr
# MNXR111473_c
# MNXR111473
# URAOX_c
# URAOX
# HCYSMT_c
# HCYSMT
# RXN-14277_c
# RXN-14277
# AMALT2_c
# AMALT2
# MNXR134966_c
# MNXR134966
# MNXR111076_c
# MNXR111076
# MNXR95636_c
# MNXR95636
# ASNS1_c
# ASNS1
# MNXR95306_c
# MNXR95306
# MNXR135986_c
# MNXR135986
# MNXR112058_c
# MNXR112058
# MNXR105357_c
# MNXR105357
# MNXR135737_c
# MNXR135737
# MNXR135988_c
# MNXR135988
# PPNCL3_c
# PPNCL3
# GPDDA4_c
# GPDDA4
# RXN-10118_c
# RXN-10118
# IPPS_c
# IPPS
# HSPMS_c
# HSPMS
# N-ACETYL-BETA-ALANINE-DEACETYLASE-RXN_c
# N-ACETYL-BETA-ALANINE-DEACETYLASE-RXN
# MNXR96330_c
# MNXR96330
# MNXR108756_c
# MNXR108756
# MNXR134582_c
# MNXR134582
# CYSS_c
# CYSS
# PEPTIDYLPROLYL-ISOMERASE-RXN_c
# PEPTIDYLPROLYL-ISOMERASE-RXN
# SHKK_c
# SHKK
# NT5C_c
# NT5C
# PPND_c
# PPND
# AASPh_c
# AASPh
# MNXR134295_c
# MNXR134295
# MNXR101697_c
# MNXR101697
# DAPE_c
# DAPE
# MNXR107155_c
# MNXR107155
# PPGPPDP_c
# PPGPPDP
# RXN0-6977_c
# RXN0-6977
# MNXR106384_c
# MNXR106384
# NTRIR2x_c
# NTRIR2x
# MNXR101863_c
# MNXR101863
# INSt2_c
# INSt2
# 3.5.4.22-RXN_c
# 3.5.4.22-RXN
# ADCPS2_c
# ADCPS2
# GALCTD_c
# GALCTD
# HMBS_c
# HMBS
# ACKr_c
# ACKr
# RXN-9523_c
# RXN-9523
# MNXR135981_c
# MNXR135981
# MNXR135880_c
# MNXR135880
# TRIOK_c
# TRIOK
# CBMD_c
# CBMD
# PYK_c
# PYK
# GLYCK_c
# GLYCK
# MNXR111157_c
# MNXR111157
# MNXR100034_c
# MNXR100034
# MNXR134855_c
# MNXR134855
# DPCOAK_c
# DPCOAK
# RXN0-5297_c
# RXN0-5297
# DGC3D_c
# DGC3D
# ATPPRT_c
# ATPPRT
# G5SADrm_c
# G5SADrm
# MNXR134507_c
# MNXR134507
# MNXR99661_c
# MNXR99661
# GMPR_c
# GMPR
# MNXR135898_c
# MNXR135898
# GAPD_c
# GAPD
# SPMDAT1_c
# SPMDAT1
# EX_h2o_e_c
# EX_h2o_e
# MI1PP_c
# MI1PP
# MNXR100285_c
# MNXR100285
# SUCCt2_3_c
# SUCCt2_3
# SPMDAT2_c
# SPMDAT2
# MNXR134905_c
# MNXR134905
# MNXR136333_c
# MNXR136333
# MNXR97421_c
# MNXR97421
# MNXR101448_c
# MNXR101448
# MNXR134898_c
# MNXR134898
# UPP3S_c
# UPP3S
# MNXR105070_c
# MNXR105070
# MNXR136334_c
# MNXR136334
# CYTDt2_c
# CYTDt2
# MNXR109030_c
# MNXR109030
# MNXR103234_c
# MNXR103234
# MNXR110686_c
# MNXR110686
# HACD1_c
# HACD1
# RXN-15840_c
# RXN-15840
# MNXR132731_c
# MNXR132731
# ADK1_c
# ADK1
# DCMPDA_c
# DCMPDA
# DHQS_c
# DHQS
# GLGC_c
# GLGC
# MNXR111463_c
# MNXR111463
# RXN-8447_c
# RXN-8447
# RXN-9661_c
# RXN-9661
# MNXR96952_c
# MNXR96952
# MNXR134526_c
# MNXR134526
# BETA-ALANOPINE-DEHYDROGENASE-RXN_c
# BETA-ALANOPINE-DEHYDROGENASE-RXN
# MNXR100142_c
# MNXR100142
# MNXR99652_c
# MNXR99652
# ARGSL_c
# ARGSL
# MNXR134397_c
# MNXR134397
# HISTP_c
# HISTP
# MNXR135846_c
# MNXR135846
# HGNTOR_c
# HGNTOR
# MNXR136226_c
# MNXR136226
# MNXR134910_c
# MNXR134910
# MNXR108451_c
# MNXR108451
# GMP5N_c
# GMP5N
# TDPGDH_c
# TDPGDH
# MNXR99602_c
# MNXR99602
# MNXR135853_c
# MNXR135853
# ACALD_c
# ACALD
# RXN-11747_c
# RXN-11747
# DXPRIi_c
# DXPRIi
# RXN-7929_c
# RXN-7929
# RXN-13680_c
# RXN-13680
# MNXR100309_c
# MNXR100309
# RXN-3142_c
# RXN-3142
# ACACT1_c
# ACACT1
# ORPT_c
# ORPT
# MNXR105370_c
# MNXR105370
# MNXR104805_c
# MNXR104805
# HYDROXYBUTYRATE-DIMER-HYDROLASE-RXN_c
# HYDROXYBUTYRATE-DIMER-HYDROLASE-RXN
# LEUabc_c
# LEUabc
# MNXR106670_c
# MNXR106670
# 1.1.1.262-RXN_c
# 1.1.1.262-RXN
# AIRCARBOXY-RXN_c
# AIRCARBOXY-RXN
# RXN-8018_c
# RXN-8018
# RXN-11970_c
# RXN-11970
# MNXR134915_c
# MNXR134915
# THMDt2_c
# THMDt2
# ALDD2x_c
# ALDD2x
# MNXR110629_c
# MNXR110629
# BZDIOLDH_c
# BZDIOLDH
# MNXR111760_c
# MNXR111760
# MNXR101887_c
# MNXR101887
# HACD9_c
# HACD9
# MELILOTATE-3-MONOOXYGENASE-RXN_c
# MELILOTATE-3-MONOOXYGENASE-RXN
# ANS_c
# ANS
# MNXR136303_c
# MNXR136303
# MNXR101677_c
# MNXR101677
# MNXR137142_c
# MNXR137142
# MNXR101055_c
# MNXR101055
# MNXR95309_c
# MNXR95309
# MNXR100113_c
# MNXR100113
# MNXR102565_c
# MNXR102565
# PEPCK_re_c
# PEPCK_re
# NTD8_c
# NTD8
# MNXR134816_c
# MNXR134816
# MNXR99877_c
# MNXR99877
# MNXR96656_c
# MNXR96656
# MNXR101186_c
# MNXR101186
# MNXR134956_c
# MNXR134956
# CYARTMT_c
# CYARTMT
# MNXR131363_c
# MNXR131363
# TRETINOLPMTACT_c
# TRETINOLPMTACT
# HISTOLDEHYD-RXN_c
# HISTOLDEHYD-RXN
# PRUK_c
# PRUK
# MNXR135724_c
# MNXR135724
# MNXR136218_c
# MNXR136218
# HPPPNDO_c
# HPPPNDO
# MNXR136259_c
# MNXR136259
# MNXR105361_c
# MNXR105361
# NH4t_c
# NH4t
# MNXR135858_c
# MNXR135858
# MNXR135885_c
# MNXR135885
# ARGDI_c
# ARGDI
# ARABISOM-RXN_c
# ARABISOM-RXN
# NFORGLUAH_c
# NFORGLUAH
# GTPCII2_c
# GTPCII2
# MNXR97451_c
# MNXR97451
# MNXR134357_c
# MNXR134357
# 3.1.4.13-RXN_c
# 3.1.4.13-RXN
# MNXR101273_c
# MNXR101273
# PPOR_c
# PPOR
# MNXR111698_c
# MNXR111698
# RXN-16055_c
# RXN-16055
# MNXR95946_c
# MNXR95946
# MNXR134914_c
# MNXR134914
# 4.1.3.35-RXN_c
# 4.1.3.35-RXN
# MNXR101144_c
# MNXR101144
# MNXR104073_c
# MNXR104073
# SARCOX_c
# SARCOX
# D-GLUTAMATE-CYCLASE-RXN_c
# D-GLUTAMATE-CYCLASE-RXN
# MNXR111640_c
# MNXR111640
# SHSL2_c
# SHSL2
# SPHINGOMYELIN-PHOSPHODIESTERASE-RXN_c
# SPHINGOMYELIN-PHOSPHODIESTERASE-RXN
# 3HAD140_c
# 3HAD140
# rxn03023_c
# rxn03023
# PALDH_c
# PALDH
# MNXR105382_c
# MNXR105382
# MNXR135829_c
# MNXR135829
# MNXR108888_c
# MNXR108888
# MNXR136252_c
# MNXR136252
# RXN-8020_c
# RXN-8020
# MCITS_c
# MCITS
# MNXR97811_c
# MNXR97811
# GPDDA1_c
# GPDDA1
# MNXR134558_c
# MNXR134558
# AGTi_c
# AGTi
# MNXR99504_c
# MNXR99504
# MNXR136310_c
# MNXR136310
# MNXR102592_c
# MNXR102592
# MNXR126589_c
# MNXR126589
# ALLTAHr_c
# ALLTAHr
# MNXR95622_c
# MNXR95622
# ORNCD_c
# ORNCD
# MNXR101363_c
# MNXR101363
# MNXR134580_c
# MNXR134580
# RXN-9531_c
# RXN-9531
# RXN-11649_c
# RXN-11649
# MNXR106818_c
# MNXR106818
# ECOAH4_c
# ECOAH4
# MNXR109714_c
# MNXR109714
# METHYLGLUTACONYL-COA-HYDRATASE-RXN_c
# METHYLGLUTACONYL-COA-HYDRATASE-RXN
# MNXR101749_c
# MNXR101749
# RXN3O-9780_c
# RXN3O-9780
# MNXR136209_c
# MNXR136209
# MNXR134814_c
# MNXR134814
# MNXR135771_c
# MNXR135771
# MNXR135768_c
# MNXR135768
# MNXR97890_c
# MNXR97890
# RXN-1781_c
# RXN-1781
# STS1_c
# STS1
# HOXPRm_c
# HOXPRm
# GLYCt_c
# GLYCt
# MNXR111514_c
# MNXR111514
# N-METHYL-2-OXOGLUTARAMATE-HYDROLASE-RXN_c
# N-METHYL-2-OXOGLUTARAMATE-HYDROLASE-RXN
# MNXR100680_c
# MNXR100680
# MNXR129847_c
# MNXR129847
# MNXR134907_c
# MNXR134907
# TPRDCOAS_c
# TPRDCOAS
# MNXR135940_c
# MNXR135940
# MNXR97469_c
# MNXR97469
# MNXR103187_c
# MNXR103187
# MNXR134296_c
# MNXR134296
# MNXR103130_c
# MNXR103130
# MNXR101167_c
# MNXR101167
# MNXR110599_c
# MNXR110599
# MNXR101764_c
# MNXR101764
# MNXR134405_c
# MNXR134405
# MNXR136205_c
# MNXR136205
# FCLPA_c
# FCLPA
# RXN-9535_c
# RXN-9535
# CHOLOYLGLYCINE-HYDROLASE-RXN_c
# CHOLOYLGLYCINE-HYDROLASE-RXN
# XAND_c
# XAND
# MNXR100789_c
# MNXR100789
# MNXR134919_c
# MNXR134919
# MNXR100621_c
# MNXR100621
# DHORTS_c
# DHORTS
# MHPGLUT_c
# MHPGLUT
# MNXR127022_c
# MNXR127022
# MNXR136143_c
# MNXR136143
# PIabc_c
# PIabc
# MNXR95656_c
# MNXR95656
# MNXR100735_c
# MNXR100735
# ASAD_c
# ASAD
# MNXR110387_c
# MNXR110387
# MNXR96722_c
# MNXR96722
# GDTP_c
# GDTP
# RXN-9870_c
# RXN-9870
# 4.3.1.14-RXN_c
# 4.3.1.14-RXN
# MDH_c
# MDH
# MNXR105027_c
# MNXR105027
# LDH_L_c
# LDH_L
# MNXR106893_c
# MNXR106893
# MNXR135884_c
# MNXR135884
# MNXR134882_c
# MNXR134882
# MNXR100885_c
# MNXR100885
# CYTDK2_c
# CYTDK2
# MNXR100295_c
# MNXR100295
# MNXR137847_c
# MNXR137847
# ACOTA_c
# ACOTA
# MNXR108919_c
# MNXR108919
# CYSDS_c
# CYSDS
# NTD2_c
# NTD2
# MNXR108012_c
# MNXR108012
# MCITL2_c
# MCITL2
# MNXR101696_c
# MNXR101696
# 2.5.1.66-RXN_c
# 2.5.1.66-RXN
# PPND2_c
# PPND2
# RBFK_c
# RBFK
# TPI_c
# TPI
# FBA3_c
# FBA3
# IDIh_c
# IDIh
# MNXR107038_c
# MNXR107038
# METabc_c
# METabc
# MNXR97035_c
# MNXR97035
# INS2D_c
# INS2D
# MNXR100252_c
# MNXR100252
# PPBNGS_c
# PPBNGS
# MNXR95220_c
# MNXR95220
# MNXR111527_c
# MNXR111527
# RXN0-6983_c
# RXN0-6983
# HACD6_c
# HACD6
# APSR_c
# APSR
# APPAT_c
# APPAT
# DADNt2_c
# DADNt2
# MNXR126492_c
# MNXR126492
# PRACHh_c
# PRACHh
# RXN-8960_c
# RXN-8960
# MNXR106406_c
# MNXR106406
# EDA_c
# EDA
# CHOLESTENONE-5-ALPHA-REDUCTASE-RXN_c
# CHOLESTENONE-5-ALPHA-REDUCTASE-RXN
# G1PTT_c
# G1PTT
# MNXR134207_c
# MNXR134207
# GLYCLTDy_c
# GLYCLTDy
# MNXR135881_c
# MNXR135881
# MNXR109136_c
# MNXR109136
# ADOCBIK_c
# ADOCBIK
# rxn14003_c
# rxn14003
# BCTA_c
# BCTA
# HYDROXYMETHYLGLUTARYL-COA-SYNTHASE-RXN_c
# HYDROXYMETHYLGLUTARYL-COA-SYNTHASE-RXN
# ZNabc_c
# ZNabc
# APATr_c
# APATr
# MNXR136331_c
# MNXR136331
# MNXR105014_c
# MNXR105014
# MNXR107174_c
# MNXR107174
# MNXR96238_c
# MNXR96238
# ECOAH7_c
# ECOAH7
# MNXR100145_c
# MNXR100145
# MNXR134856_c
# MNXR134856
# 2.3.1.43-RXN_c
# 2.3.1.43-RXN
# MNXR106675_c
# MNXR106675
# MNXR109129_c
# MNXR109129
# MNXR134506_c
# MNXR134506
# MNXR97501_c
# MNXR97501
# MNXR136233_c
# MNXR136233
# XYLI1_c
# XYLI1
# RXN-10055_c
# RXN-10055
# MNXR95310_c
# MNXR95310
# AHCYSNS_c
# AHCYSNS
# MNXR137144_c
# MNXR137144
# PPS_c
# PPS
# MNXR95250_c
# MNXR95250
# ALATA_D_c
# ALATA_D
# TAL_c
# TAL
# BENZALDEHYDE-DEHYDROGENASE-NADP+-RXN_c
# BENZALDEHYDE-DEHYDROGENASE-NADP+-RXN
# MNXR101188_c
# MNXR101188
# MNXR110639_c
# MNXR110639
# MNXR111164_c
# MNXR111164
# GALUi_c
# GALUi
# MNXR95064_c
# MNXR95064
# URIt2_c
# URIt2
# MNXR100583_c
# MNXR100583
# G1SAT_c
# G1SAT
# RIB5PISOM-RXN_c
# RIB5PISOM-RXN
# HISabc_c
# HISabc
# MNXR137717_c
# MNXR137717
# MNXR111769_c
# MNXR111769
# SHK3Dr_c
# SHK3Dr
# MNXR97467_c
# MNXR97467
# CATDOX_c
# CATDOX
# DNGALh_c
# DNGALh
# 1.13.11.41-RXN_c
# 1.13.11.41-RXN
# MNXR109252_c
# MNXR109252
# MNXR110746_c
# MNXR110746
# DCYTt2_c
# DCYTt2
# GLYCOR_nadp_c
# GLYCOR_nadp
# MNXR101874_c
# MNXR101874
# MNXR134391_c
# MNXR134391
# MNXR107829_c
# MNXR107829
# 23CN2P3_c
# 23CN2P3
# PCNO_c
# PCNO
# MNXR104643_c
# MNXR104643
# PFK_2_c
# PFK_2
# MNXR101146_c
# MNXR101146
# MNXR104039_c
# MNXR104039
# MNXR100822_c
# MNXR100822
# P5CD_c
# P5CD
# MNXR103096_c
# MNXR103096
# MNXR109849_c
# MNXR109849
# AHGDx_c
# AHGDx
# ADPT_c
# ADPT
# MNXR111041_c
# MNXR111041
# GCPN_c
# GCPN
# GLUPRT_c
# GLUPRT
# MNXR108733_c
# MNXR108733
# MCS_c
# MCS
# ATGDm_c
# ATGDm
# SPTc_c
# SPTc
# MNXR110181_c
# MNXR110181
# MNXR136338_c
# MNXR136338
# MNXR95441_c
# MNXR95441
# MNXR135726_c
# MNXR135726
# MNXR97160_c
# MNXR97160
# RXN0-4361_c
# RXN0-4361
# PRICIh_c
# PRICIh
# MNXR136260_c
# MNXR136260
# MNXR136191_c
# MNXR136191
# MNXR105383_c
# MNXR105383
# MNXR136223_c
# MNXR136223
# TMDPP_c
# TMDPP
# MNXR94946_c
# MNXR94946
# MNXR103271_c
# MNXR103271
# AGDC_c
# AGDC
# MNXR110628_c
# MNXR110628
# MNXR134334_c
# MNXR134334
# OAADC_c
# OAADC
# MNXR95411_c
# MNXR95411
# 1.1.1.127-RXN_c
# 1.1.1.127-RXN
# SUCLm_c
# SUCLm
# MNXR134868_c
# MNXR134868
# OBTFL_c
# OBTFL
# LIPATPT_c
# LIPATPT
# GDH_c
# GDH
# CYANST_c
# CYANST
# MNXR100018_c
# MNXR100018
# HPHL_c
# HPHL
# MNXR109746_c
# MNXR109746
# RXN-8963_c
# RXN-8963
# TAURabc_c
# TAURabc
# IZPN_c
# IZPN
# NTD7_c
# NTD7
# RXN-13446_c
# RXN-13446
# ABTA_c
# ABTA
# MNXR134595_c
# MNXR134595
# MNXR134657_c
# MNXR134657
# 2.1.1.99-RXN_c
# 2.1.1.99-RXN
# MNXR105177_c
# MNXR105177
# PETHCT_c
# PETHCT
# MNXR135832_c
# MNXR135832
# MNXR137160_c
# MNXR137160
# MNXR135859_c
# MNXR135859
# ORNITHINE-RACEMASE-RXN_c
# ORNITHINE-RACEMASE-RXN
# MATm_c
# MATm
# DURIK1_c
# DURIK1
# HPI_c
# HPI
# MNXR137157_c
# MNXR137157
# MNXR136212_c
# MNXR136212
# MNXR103350_c
# MNXR103350
# MNXR136139_c
# MNXR136139
# MNXR135844_c
# MNXR135844
# MNXR108360_c
# MNXR108360
# SPMDabc_c
# SPMDabc
# r0480_c
# r0480
# MNXR134191_c
# MNXR134191
# 2.5.1.39-RXN_c
# 2.5.1.39-RXN
# MINOHPKn_c
# MINOHPKn
# MNXR97154_c
# MNXR97154
# MNXR135864_c
# MNXR135864
# 2.4.1.208-RXN_c
# 2.4.1.208-RXN
# MNXR134209_c
# MNXR134209
# MNXR95055_c
# MNXR95055
# PDHbr_c
# PDHbr
# MNXR94942_c
# MNXR94942
# LTDCL_c
# LTDCL
# ARGDC_c
# ARGDC
# CPPPGO2_c
# CPPPGO2
# SERt2m_c
# SERt2m
# MNXR107081_c
# MNXR107081
# MNXR107120_c
# MNXR107120
# GTPCI_c
# GTPCI
# MNXR135825_c
# MNXR135825
# MNXR110872_c
# MNXR110872
# 2.7.10.1-RXN_c
# 2.7.10.1-RXN
# CHOLSH_c
# CHOLSH
# MNXR134886_c
# MNXR134886
# MNXR101440_c
# MNXR101440
# PI34P4P_c
# PI34P4P
# MNXR110653_c
# MNXR110653
# PNTOt4_c
# PNTOt4
# MNXR95752_c
# MNXR95752
# MNXR109735_c
# MNXR109735
# RXN-10643_c
# RXN-10643
# RXN-8982_c
# RXN-8982
# VPAMTr_c
# VPAMTr
# HMPK1_c
# HMPK1
# AOXHEXCYCL_c
# AOXHEXCYCL
# MNXR109469_c
# MNXR109469
# MNXR110533_c
# MNXR110533
# MALTATr_c
# MALTATr
# RXN0-6976_c
# RXN0-6976
# LPADSS_c
# LPADSS
# R11-RXN_c
# R11-RXN
# PPNDH_c
# PPNDH
# URFGTT_c
# URFGTT
# NTD4_c
# NTD4
# GUDBUTNAH_c
# GUDBUTNAH
# AMALT3_c
# AMALT3
# MNXR107151_c
# MNXR107151
# NMNHYD_c
# NMNHYD
# RXN0-6979_c
# RXN0-6979
# 23CN2P2_c
# 23CN2P2
# METDabc_c
# METDabc
# MNXR97821_c
# MNXR97821
# MNXR111742_c
# MNXR111742
# HSK_c
# HSK
# MNXR111690_c
# MNXR111690
# AST_c
# AST
# MNXR108054_c
# MNXR108054
# LYSAM_c
# LYSAM
# MNXR99459_c
# MNXR99459
# MNXR110988_c
# MNXR110988
# MNXR109409_c
# MNXR109409
# RXN-4821_c
# RXN-4821
# CDPMEK_c
# CDPMEK
# MNXR135980_c
# MNXR135980
# SHSL4h_c
# SHSL4h
# PGK_c
# PGK
# ADSS_c
# ADSS
# MNXR135837_c
# MNXR135837
# H2CO3D_c
# H2CO3D
# MNXR100282_c
# MNXR100282
# MNXR109134_c
# MNXR109134
# GLYCLTDx_c
# GLYCLTDx
# MNXR134893_c
# MNXR134893
# NTD11_c
# NTD11
# ARYLDIALKYL-PHOSPHATASE-RXN_c
# ARYLDIALKYL-PHOSPHATASE-RXN
# MGSA_c
# MGSA
# NTPTP1_c
# NTPTP1
# MNXR137140_c
# MNXR137140
# MI3PP_c
# MI3PP
# MNXR100469_c
# MNXR100469
# CHORS_c
# CHORS
# RXN-12448_c
# RXN-12448
# MNXR95315_c
# MNXR95315
# MNXR110643_c
# MNXR110643
# RXN0-5398_c
# RXN0-5398
# MNXR108209_c
# MNXR108209
# MNXR96105_c
# MNXR96105
# MNXR134819_c
# MNXR134819
# MNXR95253_c
# MNXR95253
# MNXR109410_c
# MNXR109410
# UDPG4E_c
# UDPG4E
# HKNDDH_c
# HKNDDH
# 2.4.1.223-RXN_c
# 2.4.1.223-RXN
# MNXR101748_c
# MNXR101748
# RXN-5901_c
# RXN-5901
# MNXR105350_c
# MNXR105350
# ALAt2pp_c
# ALAt2pp
# HAMR_c
# HAMR
# TYRTA_c
# TYRTA
# AP4AH_c
# AP4AH
# GLUCOSE-16-BISPHOSPHATE-SYNTHASE-RXN_c
# GLUCOSE-16-BISPHOSPHATE-SYNTHASE-RXN
# MNXR136820_c
# MNXR136820
# MNXR108883_c
# MNXR108883
# MNXR137158_c
# MNXR137158
# MNXR102410_c
# MNXR102410
# LYSabc_c
# LYSabc
# ACBIPGT_c
# ACBIPGT
# MNXR135848_c
# MNXR135848
# MNXR95297_c
# MNXR95297
# CHRPL_c
# CHRPL
# MNXR137715_c
# MNXR137715
# MNXR110224_c
# MNXR110224
# MNXR134927_c
# MNXR134927
# MNXR111862_c
# MNXR111862
# ACGK_c
# ACGK
# MNXR136232_c
# MNXR136232
# MNXR99637_c
# MNXR99637
# MNXR95932_c
# MNXR95932
# DGK1_c
# DGK1
# UDP-NACMURALGLDAPLIG-RXN_c
# UDP-NACMURALGLDAPLIG-RXN
# PTAr_c
# PTAr
# PUNP3_c
# PUNP3
# MNXR135823_c
# MNXR135823
# NTD5_c
# NTD5
# MNXR97325_c
# MNXR97325
# MNXR135985_c
# MNXR135985
# PTRCabc_c
# PTRCabc
# CARBAMOYL-SERINE-AMMONIA-LYASE-RXN_c
# CARBAMOYL-SERINE-AMMONIA-LYASE-RXN
# MNXR134861_c
# MNXR134861
# 3.5.1.64-RXN_c
# 3.5.1.64-RXN
# MNXR135983_c
# MNXR135983
# MNXR134505_c
# MNXR134505
# 2.3.1.156-RXN_c
# 2.3.1.156-RXN
# XANt2_c
# XANt2
# RXN-10960_c
# RXN-10960
# MNXR134336_c
# MNXR134336
# MNXR101873_c
# MNXR101873
# MNXR97480_c
# MNXR97480
# MNXR111758_c
# MNXR111758
# MNXR97524_c
# MNXR97524
# MNXR102566_c
# MNXR102566
# GALh_c
# GALh
# FORMYLASPARTATE-DEFORMYLASE-RXN_c
# FORMYLASPARTATE-DEFORMYLASE-RXN
# MNXR111694_c
# MNXR111694
# MNXR135890_c
# MNXR135890
# LDH_D_c
# LDH_D
# MNXR100304_c
# MNXR100304
# MNXR106804_c
# MNXR106804
# MNXR135935_c
# MNXR135935
# MNXR107950_c
# MNXR107950
# MNXR126124_c
# MNXR126124
# MNXR135856_c
# MNXR135856
# MNXR106667_c
# MNXR106667
# MNXR95770_c
# MNXR95770
# CAT_c
# CAT
# HPPK2_c
# HPPK2
# 3OAR100_c
# 3OAR100
# FUCOKINASE-RXN_c
# FUCOKINASE-RXN
# MNXR100936_c
# MNXR100936
# IG3PS_c
# IG3PS
# MNXR134658_c
# MNXR134658
# MNXR135725_c
# MNXR135725
# RXN-14150_c
# RXN-14150
# SBP_c
# SBP
# MNXR134926_c
# MNXR134926
# MNXR136261_c
# MNXR136261
# MNXR97159_c
# MNXR97159
# MNXR109539_c
# MNXR109539
# GPAR_c
# GPAR
# RXN-8746_c
# RXN-8746
# OXADC_c
# OXADC
# ALPHA-L-FUCOSIDASE-RXN_c
# ALPHA-L-FUCOSIDASE-RXN
# ALDD20x_1_c
# ALDD20x_1
# MNXR97808_c
# MNXR97808
# MNXR109013_c
# MNXR109013
# MNXR109324_c
# MNXR109324
# MNXR136220_c
# MNXR136220
# MNXR94952_c
# MNXR94952
# MNXR103135_c
# MNXR103135
# OXACOAL_c
# OXACOAL
# EDD_c
# EDD
# MNXR99668_c
# MNXR99668
# TRPS2_c
# TRPS2
# PRAISh_c
# PRAISh
# RXN0-5180_c
# RXN0-5180
# MNXR134873_c
# MNXR134873
# DDGLK_c
# DDGLK
# MNXR99881_c
# MNXR99881
# PACCOAL_c
# PACCOAL
# MNXR111836_c
# MNXR111836
# DINSt2_c
# DINSt2
# RPE_c
# RPE
# TRE6PH_c
# TRE6PH
# BETA-ALANYL-COA-AMMONIA-LYASE-RXN_c
# BETA-ALANYL-COA-AMMONIA-LYASE-RXN
# IMDHT_3c2hmp_c
# IMDHT_3c2hmp
# MNXR126447_c
# MNXR126447
# IPMD_c
# IPMD
# MNXR136254_c
# MNXR136254
# DPMVD_c
# DPMVD
# MNXR135887_c
# MNXR135887
# ACOAD1_c
# ACOAD1
# MALTTRabc_c
# MALTTRabc
# NITRATE-REDUCTASE-NADPH-RXN_c
# NITRATE-REDUCTASE-NADPH-RXN
# 6.3.2.26-RXN_c
# 6.3.2.26-RXN
# PCPPTh_c
# PCPPTh
# XPPT_c
# XPPT
# HISTALDEHYD-RXN_c
# HISTALDEHYD-RXN
# MNXR102595_c
# MNXR102595
# MNXR111756_c
# MNXR111756
# UPPRT_c
# UPPRT
# MNXR99538_c
# MNXR99538
# MNXR104290_c
# MNXR104290
# PREPHENATE-ASP-TRANSAMINE-RXN_c
# PREPHENATE-ASP-TRANSAMINE-RXN
# RBK_L1_c
# RBK_L1
# TRPAS2_c
# TRPAS2
# MNXR100330_c
# MNXR100330
# MNXR135770_c
# MNXR135770
# HEPT2_c
# HEPT2
# RXN-16474_c
# RXN-16474
# MNXR106938_c
# MNXR106938
# MNXR96474_c
# MNXR96474
# MNXR106947_c
# MNXR106947
# MNXR136211_c
# MNXR136211
# MNXR108066_c
# MNXR108066
# PUNP1_c
# PUNP1
# 2.5.1.71-RXN_c
# 2.5.1.71-RXN
# NNDPR_c
# NNDPR
# MNXR97073_c
# MNXR97073
# CORTISOL-O-ACETYLTRANSFERASE-RXN_c
# CORTISOL-O-ACETYLTRANSFERASE-RXN
# MNXR134949_c
# MNXR134949
# MEVK1_c
# MEVK1
# MCOATA_c
# MCOATA
# MNXR100349_c
# MNXR100349
# MNXR101165_c
# MNXR101165
# DALAt2pp_c
# DALAt2pp
# MNXR134877_c
# MNXR134877
# KAS14_c
# KAS14
# METSOXR1_c
# METSOXR1
# RXN-14063_c
# RXN-14063
# GLYCINE-AMIDINOTRANSFERASE-RXN_c
# GLYCINE-AMIDINOTRANSFERASE-RXN
# BZ12DOX_c
# BZ12DOX
# MNXR134206_c
# MNXR134206
# AMALT1_c
# AMALT1
# MNXR100253_c
# MNXR100253
# RXN-17017_c
# RXN-17017
# RXN-8014_c
# RXN-8014
# MNXR95316_c
# MNXR95316
# MNXR134885_c
# MNXR134885
# ALCD4_c
# ALCD4
# MNXR99460_c
# MNXR99460
# MNXR101441_c
# MNXR101441
# MNXR96884_c
# MNXR96884
# MNXR110652_c
# MNXR110652
# PHYCBOXL_c
# PHYCBOXL
# BPNT_c
# BPNT
# MNXR95403_c
# MNXR95403
# RXN0-5295_c
# RXN0-5295
# G3PD1_c
# G3PD1
# MNXR135610_c
# MNXR135610
# NDPK6_c
# NDPK6
# UAMAS_c
# UAMAS
# ARGN_c
# ARGN
# MNXR95302_c
# MNXR95302
# MNXR106789_c
# MNXR106789
# ICH_c
# ICH
# MNXR110534_c
# MNXR110534
# ALCOHOL-DEHYDROG-GENERIC-RXN_c
# ALCOHOL-DEHYDROG-GENERIC-RXN
# PGM_c
# PGM
# MNXR137143_c
# MNXR137143
# MNXR99672_c
# MNXR99672
# MNXR111734_c
# MNXR111734
# MNXR102302_c
# MNXR102302
# MNXR109075_c
# MNXR109075
# MIHKPP_c
# MIHKPP
# MNXR100874_c
# MNXR100874
# MNXR95312_c
# MNXR95312
# MNXR136034_c
# MNXR136034
# NNAM_c
# NNAM
# MNXR110840_c
# MNXR110840
# CTPS2_c
# CTPS2
# MNXR108060_c
# MNXR108060
# GLYOXYLATE-DEHYDROGENASE-ACYLATING-RXN_c
# GLYOXYLATE-DEHYDROGENASE-ACYLATING-RXN
# AMPTASECG_c
# AMPTASECG
# MNXR95823_c
# MNXR95823
# MNXR95665_c
# MNXR95665
# ASPabc_c
# ASPabc
# UDP-GLUCOSAMINE-EPIMERASE-RXN_c
# UDP-GLUCOSAMINE-EPIMERASE-RXN
# MNXR95410_c
# MNXR95410
# RXN-7909_c
# RXN-7909
# MNXR100655_c
# MNXR100655
# 3-OH-BENZALDEHYDE-DEHYDROG-NADP+-RXN_c
# 3-OH-BENZALDEHYDE-DEHYDROG-NADP+-RXN
# NDPK9_c
# NDPK9
# MNXR135886_c
# MNXR135886
# MNXR134894_c
# MNXR134894
# MNXR99592_c
# MNXR99592
# 2.1.3.9-RXN_c
# 2.1.3.9-RXN
# MNXR134508_c
# MNXR134508
# ATDGDm_c
# ATDGDm
# MNXR136231_c
# MNXR136231
# 2.3.1.58-RXN_c
# 2.3.1.58-RXN
# RXN0-6975_c
# RXN0-6975
# MI4PP_c
# MI4PP
# HACD4_c
# HACD4
# MNXR110037_c
# MNXR110037
# MNXR99875_c
# MNXR99875
# MNXR99905_c
# MNXR99905
# FGLU_c
# FGLU
# MNXR134906_c
# MNXR134906
# U23GAAT_c
# U23GAAT
# DAPDC_c
# DAPDC
# ECOAH12_c
# ECOAH12
# MNXR108629_c
# MNXR108629
# RXN-7745_c
# RXN-7745
# MNXR110232_c
# MNXR110232
# RXN0-1441_c
# RXN0-1441
# ACACT4m_c
# ACACT4m
# MNXR134902_c
# MNXR134902
# MG2abc_c
# MG2abc
# LNSTLS_c
# LNSTLS
# MNXR134860_c
# MNXR134860
# MNXR106668_c
# MNXR106668
# PCADYOX_c
# PCADYOX
# HADPCOADH3_c
# HADPCOADH3
# RXN-9659_c
# RXN-9659
# MNXR137892_c
# MNXR137892
# GLYCK2_c
# GLYCK2
# RXN-3341_c
# RXN-3341
# URUR-RXN_c
# URUR-RXN
# MNXR99590_c
# MNXR99590
# MNXR101401_c
# MNXR101401
# MNXR109217_c
# MNXR109217
# 2.7.7.57-RXN_c
# 2.7.7.57-RXN
# ATPS4m_c
# ATPS4m
# MNXR135847_c
# MNXR135847
# LCADi_c
# LCADi
# AMAOTr_c
# AMAOTr
# MNXR95165_c
# MNXR95165
# GLYCPDIESTER-RXN_c
# GLYCPDIESTER-RXN
# MNXR107233_c
# MNXR107233
# SGSAD_c
# SGSAD
# PPRGL_c
# PPRGL
# ECOAH9ir_c
# ECOAH9ir
# MNXR135729_c
# MNXR135729
# MNXR111481_c
# MNXR111481
# GAM_c
# GAM
# MNXR136265_c
# MNXR136265
# PRAI_c
# PRAI
# ALCD2ir_c
# ALCD2ir
# DICHLOROMETHANE-DEHALOGENASE-RXN_c
# DICHLOROMETHANE-DEHALOGENASE-RXN
# MNXR95104_c
# MNXR95104
# MNXR136336_c
# MNXR136336
# PSP_c
# PSP
# HYDROXYMETHYLGLUTARYL-COA-REDUCTASE-RXN_c
# HYDROXYMETHYLGLUTARYL-COA-REDUCTASE-RXN
# MNXR136249_c
# MNXR136249
# MNXR136204_c
# MNXR136204
# MNXR136217_c
# MNXR136217
# MNXR105362_c
# MNXR105362
# MNXR134948_c
# MNXR134948
# MNXR134528_c
# MNXR134528
# ACODA_c
# ACODA
# MNXR136262_c
# MNXR136262
# ACACT7m_c
# ACACT7m
# UROPORIIIMETHYLTRANSA-RXN_c
# UROPORIIIMETHYLTRANSA-RXN
# RXN-17388_c
# RXN-17388
# MNXR126823_c
# MNXR126823
# PERD_c
# PERD
# RBFSb_c
# RBFSb
# MNXR111666_c
# MNXR111666
# RXN-12582_c
# RXN-12582
# RNDR1_c
# RNDR1
# MNXR103232_c
# MNXR103232
# ALAR_c
# ALAR
# MNXR111759_c
# MNXR111759
# MNXR95844_c
# MNXR95844
# SADT_c
# SADT
# MCSNAH_c
# MCSNAH
# MNXR135891_c
# MNXR135891
# MNXR94887_c
# MNXR94887
# NNATm_c
# NNATm
# MNXR97782_c
# MNXR97782
# MNXR107914_c
# MNXR107914
# ACOAD8m_c
# ACOAD8m
# MNXR135934_c
# MNXR135934
# MNXR107949_c
# MNXR107949
# MNXR107776_c
# MNXR107776
# ERYTHRITOL-KINASE-RXN_c
# ERYTHRITOL-KINASE-RXN
# MNXR135830_c
# MNXR135830
# MALTabc_c
# MALTabc
# MNXR100937_c
# MNXR100937
# DHPPDA2_c
# DHPPDA2
# MNXR104638_c
# MNXR104638
# 3OAR40_1_c
# 3OAR40_1
# MNXR134955_c
# MNXR134955
# MNXR108335_c
# MNXR108335
# RXN-15099_c
# RXN-15099
# PMPK_c
# PMPK
# MNXR136309_c
# MNXR136309
# MNXR111235_c
# MNXR111235
# MNXR106754_c
# MNXR106754
# ASPCT_c
# ASPCT
# MNXR110012_c
# MNXR110012
# MNXR104079_c
# MNXR104079
# GSNK_c
# GSNK
# MNXR135857_c
# MNXR135857
# L_LACt2r_c
# L_LACt2r
# PYDXK_c
# PYDXK
# MNXR136215_c
# MNXR136215
# MNXR134590_c
# MNXR134590
# MNXR111828_c
# MNXR111828
# MNXR101275_c
# MNXR101275
# FACOAL160_c
# FACOAL160
# MNXR101766_c
# MNXR101766
# MNXR97888_c
# MNXR97888
# MNXR136207_c
# MNXR136207
# ALAD_L_c
# ALAD_L
# LYSINE-CARBAMOYLTRANSFERASE-RXN_c
# LYSINE-CARBAMOYLTRANSFERASE-RXN
# PGL_c
# PGL
# GTHPe_c
# GTHPe
# VIOMYCIN-KINASE-RXN_c
# VIOMYCIN-KINASE-RXN
# UHGADA_c
# UHGADA
# HBZOPT_c
# HBZOPT
# IMDHT_c
# IMDHT
# MNXR97351_c
# MNXR97351
# MNXR135494_c
# MNXR135494
# AACOAT_c
# AACOAT
# MNXR107066_c
# MNXR107066
# CYCLOHEXYLAMINE-OXIDASE-RXN_c
# CYCLOHEXYLAMINE-OXIDASE-RXN
# MNXR134952_c
# MNXR134952
# CTPS1_c
# CTPS1
# SAM24MT_c
# SAM24MT
# MNXR112107_c
# MNXR112107
# MNXR134416_c
# MNXR134416
# MNXR136253_c
# MNXR136253
# MNXR97452_c
# MNXR97452
# MNXR108206_c
# MNXR108206
# PNTK_c
# PNTK
# UAGPT2_c
# UAGPT2
# RXN-8019_c
# RXN-8019
# MNXR111477_c
# MNXR111477
# 3OAR140_c
# 3OAR140
# MNXR125908_c
# MNXR125908
# GLUabc_c
# GLUabc
# CBPS_c
# CBPS
# MNXR135939_c
# MNXR135939
# TYRCBOX_c
# TYRCBOX
# MNXR96813_c
# MNXR96813
# ME1_c
# ME1
# ACOATA_c
# ACOATA
# GTPDPK_c
# GTPDPK
# FUM_c
# FUM
# RXN-10080_c
# RXN-10080
# MNXR99909_c
# MNXR99909
# GPDDA2_c
# GPDDA2
# MNXR108111_c
# MNXR108111
# PDHam1hi_c
# PDHam1hi
# MNXR101693_c
# MNXR101693
# PPM2_c
# PPM2
# RXN-14226_c
# RXN-14226
# THRS_c
# THRS
# CU2abcpp_c
# CU2abcpp
# ANPRT_c
# ANPRT
# RZ5PP_c
# RZ5PP
# ADECn_c
# ADECn
# CYTDK1_c
# CYTDK1
# MNXR110598_c
# MNXR110598
# MNXR101039_c
# MNXR101039
# 34HPPOR_c
# 34HPPOR
# UDPGALM_c
# UDPGALM
# X5PL3E_c
# X5PL3E
# MNXR107994_c
# MNXR107994
# GLYBabc_c
# GLYBabc
# PIt2m_c
# PIt2m
# MNXR101872_c
# MNXR101872
# PNP_c
# PNP
# MNXR108184_c
# MNXR108184
# MNXR109233_c
# MNXR109233
# ANNAT_c
# ANNAT
# ACACT5r_1_c
# ACACT5r_1
# 4HTHRS_c
# 4HTHRS
# MNXR100734_c
# MNXR100734
# ACETATE-KINASE-PYROPHOSPHATE-RXN_c
# ACETATE-KINASE-PYROPHOSPHATE-RXN
# MAL6PG_c
# MAL6PG
# UREA_c
# UREA
# PNTEH_c
# PNTEH
# XYLI2_c
# XYLI2
# ALANA1tm_c
# ALANA1tm
# DRPA_c
# DRPA
# RXN-10665_c
# RXN-10665
# MNXR134792_c
# MNXR134792
# MNXR105173_c
# MNXR105173
# MNXR109113_c
# MNXR109113
# MNXR134890_c
# MNXR134890
# TMN_c
# TMN
# MNXR97379_c
# MNXR97379
# SACCD2_c
# SACCD2
# DDPGA_c
# DDPGA
# UAPGR_c
# UAPGR
# CPPPGO_c
# CPPPGO
# SDPTA_c
# SDPTA
# MNXR95427_c
# MNXR95427
# MNXR95866_c
# MNXR95866
# MCCC_c
# MCCC
# TRPt2m_c
# TRPt2m
# MNXR107039_c
# MNXR107039
# MNXR135888_c
# MNXR135888
# MNXR109745_c
# MNXR109745
# MNXR111673_c
# MNXR111673
# MNXR99669_c
# MNXR99669
# MNXR135882_c
# MNXR135882
# LEUCINE-23-AMINOMUTASE-RXN_c
# LEUCINE-23-AMINOMUTASE-RXN
# MNXR99621_c
# MNXR99621
# RXN-2364_c
# RXN-2364
# RXN-11372_c
# RXN-11372
# CMS_c
# CMS
# MNXR97781_c
# MNXR97781
# ADOCBLS_c
# ADOCBLS
# MNXR104858_c
# MNXR104858
# PRADPh_c
# PRADPh
# DMATT_c
# DMATT
# MNXR108804_c
# MNXR108804
# RXN-9718_c
# RXN-9718
# MNXR109693_c
# MNXR109693
# ENO_c
# ENO
# URCN_c
# URCN
# MNXR134433_c
# MNXR134433
# MNXR137161_c
# MNXR137161
# PRPPSYN-RXN_c
# PRPPSYN-RXN
# MNXR136330_c
# MNXR136330
# SULabc_c
# SULabc
# MNXR107173_c
# MNXR107173
# LACTOSE-6-PHOSPHATE-ISOMERASE-RXN_c
# LACTOSE-6-PHOSPHATE-ISOMERASE-RXN
# MNXR135850_c
# MNXR135850
# FE3abc_c
# FE3abc
# NA1Hth_c
# NA1Hth
# MNXR100067_c
# MNXR100067
# MNXR108080_c
# MNXR108080
# MNXR136230_c
# MNXR136230
# 3.5.4.30-RXN_c
# 3.5.4.30-RXN
# ACS_c
# ACS
# PRDX_c
# PRDX
# PYNP2r_c
# PYNP2r
# MNXR101988_c
# MNXR101988
# MNXR107626_c
# MNXR107626
# OMCDC_c
# OMCDC
# PROabc_c
# PROabc
# MNXR136192_c
# MNXR136192
# MNXR136306_c
# MNXR136306
# TMDK1_c
# TMDK1
# MNXR102011_c
# MNXR102011
# COBALT2tex_c
# COBALT2tex
# ASPATh_c
# ASPATh
# MNXR136001_c
# MNXR136001
# MNXR101986_c
# MNXR101986
# 4.99.1.7-RXN_c
# 4.99.1.7-RXN
# UAGCVT_c
# UAGCVT
# METSOX1abcpp_c
# METSOX1abcpp
# HACDp_c
# HACDp
# DGGH_c
# DGGH
# GLUTAMATE-1-KINASE-RXN_c
# GLUTAMATE-1-KINASE-RXN
# PROPANOATECOA-LIGASE-RXN_c
# PROPANOATECOA-LIGASE-RXN
# MNXR134815_c
# MNXR134815
# MNXR111792_c
# MNXR111792
# 2.7.1.127-RXN_c
# 2.7.1.127-RXN
# AGMT_c
# AGMT
# ADSL2r_c
# ADSL2r
# MNXR134210_c
# MNXR134210
# MNXR136225_c
# MNXR136225
# MNXR111910_c
# MNXR111910
# GGTT_c
# GGTT
# MNXR105340_c
# MNXR105340
# RAFGH_c
# RAFGH
# MNXR111764_c
# MNXR111764
# MNXR135933_c
# MNXR135933
# ASPULVINONE-DIMETHYLALLYLTRANSFERASE-RXN_c
# ASPULVINONE-DIMETHYLALLYLTRANSFERASE-RXN
# AIRS-RXN_c
# AIRS-RXN
# MNXR135728_c
# MNXR135728
# MNXR100679_c
# MNXR100679
# MNXR135854_c
# MNXR135854
# MNXR109328_c
# MNXR109328
# MNXR99614_c
# MNXR99614
# MNXR107413_c
# MNXR107413
# ADOCBIAH_c
# ADOCBIAH
# GGTAe2_c
# GGTAe2
# MNXR95639_c
# MNXR95639
# MNXR100623_c
# MNXR100623
# MNXR97477_c
# MNXR97477
# MNXR135727_c
# MNXR135727
# FKYNH_c
# FKYNH
# GND_c
# GND
# MNXR135862_c
# MNXR135862
# BDH_c
# BDH
# MNXR136263_c
# MNXR136263
# MNXR97172_c
# MNXR97172
# PAPSR_c
# PAPSR
# MNXR97161_c
# MNXR97161
# AHHST_c
# AHHST
# PYDXNK_c
# PYDXNK
# MDHC_nadp_hr_c
# MDHC_nadp_hr
# NTD10_c
# NTD10
# URIDK2m_c
# URIDK2m
# FDH_c
# FDH
# MNXR109011_c
# MNXR109011
# RXN1F-19_c
# RXN1F-19
# MNXR136222_c
# MNXR136222
# MNXR96247_c
# MNXR96247
# MNXR95251_c
# MNXR95251
# MNXR135989_c
# MNXR135989
# PYDAMK_c
# PYDAMK
# RXN-8675_c
# RXN-8675
# MNXR134261_c
# MNXR134261
# NITROGENASE-RXN_c
# NITROGENASE-RXN
# ALDD19xr_c
# ALDD19xr
# MNXR108808_c
# MNXR108808
# RXN-9774_c
# RXN-9774
# MNXR94877_c
# MNXR94877
# DCYTD_c
# DCYTD
# 1.2.1.65-RXN_c
# 1.2.1.65-RXN
# MNXR97157_c
# MNXR97157
# MNXR134876_c
# MNXR134876
# MCITD_c
# MCITD
# PSCIT_c
# PSCIT
# NDPK4_c
# NDPK4
# ADCL_c
# ADCL
# HDC_c
# HDC
# MNXR101751_c
# MNXR101751
# MNXR109353_c
# MNXR109353
# RXN-14204_c
# RXN-14204
# HACD2_c
# HACD2
# MNXR100810_c
# MNXR100810
# ACACT10m_c
# ACACT10m
# MNXR97975_c
# MNXR97975
# URIK2_c
# URIK2
# MNXR108494_c
# MNXR108494
# MNXR136214_c
# MNXR136214
# ADCS_c
# ADCS
# MNXR99641_c
# MNXR99641
# MNXR134425_c
# MNXR134425
# MNXR109540_c
# MNXR109540
# R122-RXN_c
# R122-RXN
# BCTA_val_h_c
# BCTA_val_h
# PGLYCP_c
# PGLYCP
# FERO_c
# FERO
# AHEXASE3_c
# AHEXASE3
# BISPHOSPHOGLYCERATE-MUTASE-RXN_c
# BISPHOSPHOGLYCERATE-MUTASE-RXN
# RXN-9773_c
# RXN-9773
# MNXR134591_c
# MNXR134591
# DHQTi_c
# DHQTi
# MNXR109216_c
# MNXR109216
# MNXR103150_c
# MNXR103150
# GDR_nadp_h_c
# GDR_nadp_h
# R268-RXN_c
# R268-RXN
# HYDGLUTSYN-RXN_c
# HYDGLUTSYN-RXN
# MNXR110899_c
# MNXR110899
# MNXR134951_c
# MNXR134951
# ATDAMh_c
# ATDAMh
# MNXR107262_c
# MNXR107262
# MNXR97471_c
# MNXR97471
# MNXR110813_c
# MNXR110813
# MNXR100237_c
# MNXR100237
# MNXR135826_c
# MNXR135826
# 2.7.8.22-RXN_c
# 2.7.8.22-RXN
# GLYK_c
# GLYK
# RETINOL-O-FATTY-ACYLTRANSFERASE-RXN_c
# RETINOL-O-FATTY-ACYLTRANSFERASE-RXN
# 23CN2P1_c
# 23CN2P1
# MNXR134757_c
# MNXR134757
# MNXR102063_c
# MNXR102063
# 2-HYDROXY-3-OXOADIPATE-SYNTHASE-RXN_c
# 2-HYDROXY-3-OXOADIPATE-SYNTHASE-RXN
# 3OAR80_c
# 3OAR80
# ARGININE-RACEMASE-RXN_c
# ARGININE-RACEMASE-RXN
# OPHBDC_c
# OPHBDC
# 1.8.1.5-RXN_c
# 1.8.1.5-RXN
# MNXR109176_c
# MNXR109176
# GLYCOLALDREDUCT-RXN_c
# GLYCOLALDREDUCT-RXN
# MNXR107521_c
# MNXR107521
# MNXR109771_c
# MNXR109771
# MNXR136203_c
# MNXR136203
# NADTRHD_c
# NADTRHD
# DHPD_c
# DHPD
# SGDS_c
# SGDS
# PHENYLALANINE-AMMONIA-LYASE-RXN_c
# PHENYLALANINE-AMMONIA-LYASE-RXN
# 5.1.1.16-RXN_c
# 5.1.1.16-RXN
# MNXR111211_c
# MNXR111211
# ALKP_c
# ALKP
# MNXR99858_c
# MNXR99858
# MNXR108981_c
# MNXR108981
# 2.5.1.51-RXN_c
# 2.5.1.51-RXN
# 23CN2P4_c
# 23CN2P4
# MNXR109175_c
# MNXR109175
# MNXR109090_c
# MNXR109090
# BETA-9-CYTOKININ-ALANINE-SYNTHASE-RXN_c
# BETA-9-CYTOKININ-ALANINE-SYNTHASE-RXN
# MNXR101910_c
# MNXR101910
# ACACT2_c
# ACACT2
# IMPD_c
# IMPD
# GAPDH_nadp_hi_c
# GAPDH_nadp_hi
# MNXR108554_c
# MNXR108554
# MNXR134806_c
# MNXR134806
# PGMT_c
# PGMT
# HCYSMT2_c
# HCYSMT2
# 4ABUTD_c
# 4ABUTD
# MNXR134820_c
# MNXR134820
# RNMK_c
# RNMK
# MNXR108083_c
# MNXR108083
# MNXR101993_c
# MNXR101993
# RXN0-6978_c
# RXN0-6978
# MNXR102874_c
# MNXR102874
# ARGabc_c
# ARGabc
# MNXR136335_c
# MNXR136335
# RXN-12559_c
# RXN-12559
# MNXR104329_c
# MNXR104329
# MNXR111466_c
# MNXR111466
# DDPA_c
# DDPA
# MNXR111735_c
# MNXR111735
# MNXR97326_c
# MNXR97326
# HYPOTAURINE-DEHYDROGENASE-RXN_c
# HYPOTAURINE-DEHYDROGENASE-RXN
# RDH1_c
# RDH1
# RXN66-221_c
# RXN66-221
# LYSRC_c
# LYSRC
# MNXR106812_c
# MNXR106812
# MNXR101481_c
# MNXR101481
# DXPS_c
# DXPS
# MNXR97032_c
# MNXR97032
# PGCD_c
# PGCD
# 3HCINNMH_c
# 3HCINNMH
# GALT_c
# GALT
# AEPPYRTA_c
# AEPPYRTA
# FGAMSYN-RXN_c
# FGAMSYN-RXN
# MNXR136229_c
# MNXR136229
# MNXR100068_c
# MNXR100068
# HEX1_c
# HEX1
# MNXR107641_c
# MNXR107641
# MNXR108969_c
# MNXR108969
# MNXR104931_c
# MNXR104931
# MNXR135852_c
# MNXR135852
# MNXR106678_c
# MNXR106678
# RXN0-6974_c
# RXN0-6974
# ASP1DC_c
# ASP1DC
# MNXR100300_c
# MNXR100300
# MNXR110642_c
# MNXR110642
# MNXR106671_c
# MNXR106671
# RXN-4303_c
# RXN-4303
# MNXR107470_c
# MNXR107470
# PUNP2_c
# PUNP2
# ARGDh_c
# ARGDh
# BCTA_glu_h_c
# BCTA_glu_h
# MNXR111160_c
# MNXR111160
# RXN-9663_c
# RXN-9663
# RIBabc_c
# RIBabc
# NAPHTHOATE-SYN-RXN_c
# NAPHTHOATE-SYN-RXN
# ABUTD_c
# ABUTD
# MNXR96325_c
# MNXR96325
# MNXR111858_c
# MNXR111858
# MNXR100748_c
# MNXR100748
# FACOAL180_c
# FACOAL180
# RXN-9662_c
# RXN-9662
# VICIANIN-BETA-GLUCOSIDASE-RXN_c
# VICIANIN-BETA-GLUCOSIDASE-RXN
# 3.1.3.14-RXN_c
# 3.1.3.14-RXN
# D-LYSOPINE-DEHYDROGENASE-RXN_c
# D-LYSOPINE-DEHYDROGENASE-RXN
# MNXR97472_c
# MNXR97472
# MG2t_c
# MG2t
# MNXR135849_c
# MNXR135849
# NTD6_c
# NTD6
# DPR_c
# DPR
# MNXR104466_c
# MNXR104466
# NADK_c
# NADK
# MNXR95387_c
# MNXR95387
# LYSOLECITHIN-ACYLMUTASE-RXN_c
# LYSOLECITHIN-ACYLMUTASE-RXN
# MNXR99841_c
# MNXR99841
# NNDMBRT_c
# NNDMBRT
# MNXR111060_c
# MNXR111060
# MNXR136213_c
# MNXR136213
# PUNP4_c
# PUNP4
# MNXR136305_c
# MNXR136305
# MNXR134817_c
# MNXR134817
# MNXR107552_c
# MNXR107552
# SHCHF_c
# SHCHF
# MNXR136155_c
# MNXR136155
# COA-GLUTATHIONE-REDUCTASE-NADPH-RXN_c
# COA-GLUTATHIONE-REDUCTASE-NADPH-RXN
# R01465m_c
# R01465m
# DBTS_c
# DBTS
# 2.7.7.36-RXN_c
# 2.7.7.36-RXN
# MNXR136219_c
# MNXR136219
# MNXR134754_c
# MNXR134754
# GALS4_c
# GALS4
# HYDROXYMETHYLGLUTARYL-COA-LYASE-RXN_c
# HYDROXYMETHYLGLUTARYL-COA-LYASE-RXN
# MNXR136256_c
# MNXR136256
# RXN-11184_c
# RXN-11184
# SERD_D_c
# SERD_D
# MNXR100546_c
# MNXR100546
# THRA_c
# THRA
# ACOAD9m_c
# ACOAD9m
# HETZK_c
# HETZK
# CYTD_c
# CYTD
# MNLDH2_c
# MNLDH2
# ADNK1_c
# ADNK1
# MNXR100634_c
# MNXR100634
# MNXR135982_c
# MNXR135982
# MNXR95106_c
# MNXR95106
# RNDR2_c
# RNDR2
# MNXR135938_c
# MNXR135938
# ADSHm_c
# ADSHm
# TDPDRR_c
# TDPDRR
# MNXR110034_c
# MNXR110034
# MNXR134872_c
# MNXR134872
# RXN-8574_c
# RXN-8574
# 1TRANSKETO-RXN_c
# 1TRANSKETO-RXN
# OPAH_c
# OPAH
# MNXR135831_c
# MNXR135831
# GCC2cm_c
# GCC2cm
# AMPDA_c
# AMPDA
# MNXR111757_c
# MNXR111757
# HDH_c
# HDH
# MNXR111793_c
# MNXR111793
# MNXR94881_c
# MNXR94881
# TMPK_c
# TMPK
# MNXR110660_c
# MNXR110660
# MNXR99636_c
# MNXR99636
# MNXR107912_c
# MNXR107912
# MNXR95709_c
# MNXR95709
# MNXR135828_c
# MNXR135828
# MNXR135855_c
# MNXR135855
# IGPDH_c
# IGPDH
# GNK_c
# GNK
# MNXR101353_c
# MNXR101353
# MNXR108885_c
# MNXR108885
# MNXR136311_c
# MNXR136311
# ARGSS_c
# ARGSS
# MNXR101702_c
# MNXR101702
# MNXR104035_c
# MNXR104035
# RXN-14149_c
# RXN-14149
# MNXR135863_c
# MNXR135863
# 5.1.2.3-RXN_c
# 5.1.2.3-RXN
# CEREBROSIDE-SULFATASE-RXN_c
# CEREBROSIDE-SULFATASE-RXN
# RXN-8930_c
# RXN-8930
# MNXR102398_c
# MNXR102398
# AFAT_c
# AFAT
# MNXR96248_c
# MNXR96248
# RNDR3_c
# RNDR3
# PROPKIN-RXN_c
# PROPKIN-RXN
# RXN-17021_c
# RXN-17021
# GLYCDH_1_c
# GLYCDH_1
# MNXR137159_c
# MNXR137159
# MNXR96962_c
# MNXR96962
# TYRt2m_c
# TYRt2m
# MNXR135765_c
# MNXR135765
# ILEabc_c
# ILEabc
# MNXR136255_c
# MNXR136255
# MNXR97400_c
# MNXR97400
# MNXR111513_c
# MNXR111513
# AKGDH_c
# AKGDH
# MNXR134353_c
# MNXR134353
# MNXR134439_c
# MNXR134439
# GLNLASEer_c
# GLNLASEer
# BIOTINIDASE-RXN_c
# BIOTINIDASE-RXN
# MNXR104038_c
# MNXR104038
# PLASMALOGEN-SYNTHASE-RXN_c
# PLASMALOGEN-SYNTHASE-RXN
# MICITDr_c
# MICITDr
# SADH_c
# SADH
# RXN-9539_c
# RXN-9539
# CBMKr_c
# CBMKr
# ECOAH6_c
# ECOAH6
# NTD1_c
# NTD1
# MNXR137141_c
# MNXR137141
# 2-OCTAPRENYLPHENOL-HYDROX-RXN_c
# 2-OCTAPRENYLPHENOL-HYDROX-RXN
# MNXR95071_c
# MNXR95071
# MNXR134911_c
# MNXR134911
# KHte_c
# KHte
# 25-DIOXOPIPERAZINE-HYDROLASE-RXN_c
# 25-DIOXOPIPERAZINE-HYDROLASE-RXN
# MNXR96094_c
# MNXR96094
# MNXR134881_c
# MNXR134881
# MNXR99903_c
# MNXR99903
# 2.7.7.34-RXN_c
# 2.7.7.34-RXN
# G5DHx_c
# G5DHx
# MNXR102198_c
# MNXR102198
# PUNP7_c
# PUNP7
# MNXR108918_c
# MNXR108918
# GLUS_nadph_c
# GLUS_nadph
# MNXR103420_c
# MNXR103420
# UMPK_c
# UMPK
# R524-RXN_c
# R524-RXN
# URIK1_c
# URIK1
# MNXR101698_c
# MNXR101698
# MNXR111785_c
# MNXR111785
# HIUH_c
# HIUH
# MNXR110584_c
# MNXR110584
# MNXR135827_c
# MNXR135827
# MNXR96326_c
# MNXR96326
# MNXR96758_c
# MNXR96758
# O2t_c
# O2t
# RXN-8999_c
# RXN-8999
# GALACTONOLACTONASE-RXN_c
# GALACTONOLACTONASE-RXN
# FPPSh_c
# FPPSh
# MNXR125940_c
# MNXR125940
# 2.7.4.19-RXN_c
# 2.7.4.19-RXN
# HSST_c
# HSST
# MNXR100254_c
# MNXR100254
# CHLt2_c
# CHLt2
# MNXR97206_c
# MNXR97206
# ACONTa_c
# ACONTa
# MNXR108757_c
# MNXR108757
# 3HPPPNH_c
# 3HPPPNH
# RXN3DJ-170_c
# RXN3DJ-170
# PHEPC_c
# PHEPC
# UAMAGS_c
# UAMAGS
# MNXR135018_c
# MNXR135018
# MNXR109459_c
# MNXR109459
# MNXR135984_c
# MNXR135984
# MNXR102373_c
# MNXR102373
# GUAD_c
# GUAD
# MNXR97823_c
# MNXR97823
# RXN-10972_c
# RXN-10972
# RXN-4305_c
# RXN-4305
# MNXR134274_c
# MNXR134274
# DKDID_c
# DKDID
# INSK_c
# INSK
# MNXR110579_c
# MNXR110579
# UPPDC1_c
# UPPDC1
# MNXR136199_c
# MNXR136199
# DDPGALA_c
# DDPGALA
# NDPK3_c
# NDPK3
# SUCBZL_c
# SUCBZL
# MNXR111675_c
# MNXR111675
# 3OXCOAT_c
# 3OXCOAT
# GALACTURONOKINASE-RXN_c
# GALACTURONOKINASE-RXN
# MNXR97468_c
# MNXR97468
# ICHORS_c
# ICHORS
# MNXR135883_c
# MNXR135883
# TMK_c
# TMK
# MNXR105188_c
# MNXR105188
# APNPT_c
# APNPT
# PPENTOMUT-RXN_c
# PPENTOMUT-RXN
# MNXR134586_c
# MNXR134586
# PUNP6_c
# PUNP6
# GALKh_c
# GALKh
# MNXR95313_c
# MNXR95313
# O-SUCCINYLBENZOATE-COA-SYN-RXN_c
# O-SUCCINYLBENZOATE-COA-SYN-RXN
# ALLANTOATE-DEIMINASE-RXN_c
# ALLANTOATE-DEIMINASE-RXN
# MNXR95451_c
# MNXR95451
# MNXR111465_c
# MNXR111465
# MNXR134600_c
# MNXR134600
# MNXR97473_c
# MNXR97473
# GLUR_c
# GLUR
# NDPK10_c
# NDPK10
# RXN-9658_c
# RXN-9658
# MNXR109025_c
# MNXR109025
# MNXR110745_c
# MNXR110745
# URAt2_c
# URAt2
# ALDD22x_c
# ALDD22x
# CORTICOSTEROID-SIDE-CHAIN-ISOMERASE-RXN_c
# CORTICOSTEROID-SIDE-CHAIN-ISOMERASE-RXN
# MNXR108153_c
# MNXR108153
# MNXR102303_c
# MNXR102303
# MNXR135845_c
# MNXR135845
# 2.5.1.70-RXN_c
# 2.5.1.70-RXN
# r0789_c
# r0789
# MNXR111926_c
# MNXR111926
# 4-NITROPHENYLPHOSPHATASE-RXN_c
# 4-NITROPHENYLPHOSPHATASE-RXN
# CS_c
# CS
# MNXR97418_c
# MNXR97418
# MNXR99623_c
# MNXR99623
# MNXR136228_c
# MNXR136228
# NADS1_c
# NADS1
# MNXR97470_c
# MNXR97470
# UAGAAT_c
# UAGAAT
# 4-HYDROXYBENZOATE-DECARBOXYLASE-RXN_c
# 4-HYDROXYBENZOATE-DECARBOXYLASE-RXN
# VALabc_c
# VALabc
# RXN-17385_c
# RXN-17385
# MNXR97479_c
# MNXR97479
# ASPT_c
# ASPT
# ADCPS1_c
# ADCPS1
# ECOAH1_c
# ECOAH1
# MNXR134865_c
# MNXR134865
# DADA_c
# DADA
# RMPA_c
# RMPA
# GGGABAH_c
# GGGABAH
# MNXR104879_c
# MNXR104879
# CHOLD_c
# CHOLD
# RXN-9860_c
# RXN-9860
# MNXR102142_c
# MNXR102142
# 1.8.3.5-RXN_c
# 1.8.3.5-RXN
# MNXR134857_c
# MNXR134857
# AOXSr_c
# AOXSr
# MNXR111692_c
# MNXR111692
# MNXR134918_c
# MNXR134918
# DURIPP_c
# DURIPP
# ACGAM2E_c
# ACGAM2E
# PGAMT_c
# PGAMT
# MNXR102563_c
# MNXR102563
# Kt1_c
# Kt1
# MNXR97433_c
# MNXR97433
# THDPS_c
# THDPS
# MNXR135987_c
# MNXR135987
# THIORDXi_c
# THIORDXi
# GK1_c
# GK1
# MNXR105310_c
# MNXR105310
# MNXR105308_c
# MNXR105308
# AGGPR_c
# AGGPR
# USHD_c
# USHD
# PANTS_c
# PANTS
# PUTA3_c
# PUTA3
# MNXR111691_c
# MNXR111691
# SULR_c
# SULR
# MNXR135936_c
# MNXR135936
# 34DHOXPEGOX_c
# 34DHOXPEGOX
# MNXR111762_c
# MNXR111762
# MNXR136304_c
# MNXR136304
# MNXR108523_c
# MNXR108523
# MNXR127034_c
# MNXR127034
# MNXR109327_c
# MNXR109327
# MPPM_c
# MPPM
# MNXR132627_c
# MNXR132627
# ALPHNH_c
# ALPHNH
# IGPS_c
# IGPS
# MNXR136264_c
# MNXR136264
# LACTATE-ALDOLASE-RXN_c
# LACTATE-ALDOLASE-RXN
# AGDI_c
# AGDI
# MNXR136337_c
# MNXR136337
# MNXR99642_c
# MNXR99642
# MNXR136216_c
# MNXR136216
# MNXR136257_c
# MNXR136257
# ACACCT_c
# ACACCT
# SERH_c
# SERH
# MNXR135860_c
# MNXR135860
# PPCDC_c
# PPCDC
# AGMHE_c
# AGMHE
# MNXR95362_c
# MNXR95362
# MNXR100294_c
# MNXR100294
# DUTPDP_c
# DUTPDP
# ADA_c
# ADA
# PFK_3_c
# PFK_3
# RXN-8500_c
# RXN-8500
# MNXR100468_c
# MNXR100468
# MNXR136251_c
# MNXR136251
# MNXR104447_c
# MNXR104447
# MNXR135843_c
# MNXR135843
# RXN-13279_c
# RXN-13279
# MNXR104070_c
# MNXR104070
# MNXR109024_c
# MNXR109024
# MNXR135937_c
# MNXR135937
# MNXR134211_c
# MNXR134211
# MNXR137901_c
# MNXR137901
# R128-RXN_c
# R128-RXN
# DTMPK_c
# DTMPK
# MNXR134869_c
# MNXR134869
# MNXR94876_c
# MNXR94876
# ACACT6m_c
# ACACT6m
# PENTANAMIDASE-RXN_c
# PENTANAMIDASE-RXN
# MNXR107913_c
# MNXR107913
# MNXR97155_c
# MNXR97155
# MNXR109012_c
# MNXR109012
# THMabc_c
# THMabc
# MNXR134923_c
# MNXR134923
# PDX5POi_c
# PDX5POi
# GLYOX_c
# GLYOX
# APRAUR_c
# APRAUR
# MCPST_c
# MCPST
# MNXR100544_c
# MNXR100544
# GART_c
# GART
# ALLIIN-LYASE-RXN_c
# ALLIIN-LYASE-RXN
# OXOAEL_c
# OXOAEL
# G6PDH2er_c
# G6PDH2er
# MNXR137145_c
# MNXR137145
# GLYAT_c
# GLYAT
# 5.4.99.14-RXN_c
# 5.4.99.14-RXN
# MNXR136308_c
# MNXR136308
# MNXR135613_c
# MNXR135613
# PROPIONATE--COA-LIGASE-RXN_c
# PROPIONATE--COA-LIGASE-RXN
# MNXR111149_c
# MNXR111149
# MNXR105164_c
# MNXR105164
# OCBT_c
# OCBT
# MNXR135216_c
# MNXR135216
# MNXR135889_c
# MNXR135889
# MNXR136033_c
# MNXR136033
# MNXR103269_c
# MNXR103269
# MNXR101267_c
# MNXR101267
# MNXR136208_c
# MNXR136208
# MNXR134185_c
# MNXR134185
# RXN-7919_c
# RXN-7919
# HOMOCITRATE-SYNTHASE-RXN_c
# HOMOCITRATE-SYNTHASE-RXN
# MNXR100841_c
# MNXR100841
# MNXR135766_c
# MNXR135766
# PSAT_c
# PSAT
# DHFS_c
# DHFS
# 2.5.1.43-RXN_c
# 2.5.1.43-RXN
# MNXR97401_c
# MNXR97401
# 2DHPFALDL_c
# 2DHPFALDL
# MNXR134953_c
# MNXR134953
# MNXR134360_c
# MNXR134360
# MNXR102594_c
# MNXR102594
# PFL_c
# PFL
# MNXR134462_c
# MNXR134462
# RNDR4_c
# RNDR4
# MNXR109719_c
# MNXR109719
# MNXR134243_c
# MNXR134243
# AMALT4_c
# AMALT4
# MNXR100310_c
# MNXR100310
# TDSRh_c
# TDSRh
# SDPDS_c
# SDPDS
# CO2t_c
# CO2t
# NDPK2_c
# NDPK2
# RXN-9527_c
# RXN-9527
# MNXR104889_c
# MNXR104889
# MNXR134922_c
# MNXR134922
# OHPHM_c
# OHPHM
# MALS_c
# MALS
# MNXR126663_c
# MNXR126663
# OHPBAT_c
# OHPBAT
# MNXR100281_c
# MNXR100281
# RXN-13179_c
# RXN-13179
# PHETA1_c
# PHETA1
# PROLINE-RACEMASE-RXN_c
# PROLINE-RACEMASE-RXN
# MNXR135769_c
# MNXR135769
# GLYOX_1_c
# GLYOX_1
# MNXR105033_c
# MNXR105033
# SERPT_c
# SERPT
# MNXR134880_c
# MNXR134880
# MNXR94796_c
# MNXR94796
# MNXR108565_c
# MNXR108565
# NDPK8_c
# NDPK8
# MNXR101747_c
# MNXR101747
# MOAT2_c
# MOAT2
# MNXR134887_c
# MNXR134887
# MNXR134883_c
# MNXR134883
# CLtex_c
# CLtex
# MNXR134932_c
# MNXR134932
# MNXR134888_c
# MNXR134888
# ALAALAr_c
# ALAALAr
# MNXR94886_c
# MNXR94886
# MNXR135833_c
# MNXR135833
# MNXR100228_c
# MNXR100228
# MNXR134930_c
# MNXR134930
# MNXR134935_c
# MNXR134935
# GMHEPAT_c
# GMHEPAT
# GCALDD_c
# GCALDD
# RXN0-4341_c
# RXN0-4341
# MNXR134934_c
# MNXR134934
# SHCHD2_c
# SHCHD2
# UDP-NACMURALGLDAPAALIG-RXN_c
# UDP-NACMURALGLDAPAALIG-RXN
# MNXR100227_c
# MNXR100227
# S7PI_c
# S7PI
# MNXR109301_c
# MNXR109301
# MNXR108110_c
# MNXR108110
# MNXR100606_c
# MNXR100606
# MNXR100598_c
# MNXR100598
# MNXR100599_c
# MNXR100599
# MNXR134931_c
# MNXR134931
# MNXR134941_c
# MNXR134941
# MNXR134858_c
# MNXR134858
# MNXR96437_c
# MNXR96437
# MNXR134903_c
# MNXR134903
# AUS_c
# AUS
# MNXR134862_c
# MNXR134862
# MNXR134895_c
# MNXR134895
# MOAT_c
# MOAT
# MNXR134866_c
# MNXR134866
# MNXR134899_c
# MNXR134899
# MNXR134878_c
# MNXR134878
# MNXR100015_c
# MNXR100015
# MNXR134933_c
# MNXR134933
# MNXR134940_c
# MNXR134940
# MNXR134936_c
# MNXR134936
# MNXR101686_c
# MNXR101686
# MNXR135774_c
# MNXR135774
# MNXR134938_c
# MNXR134938
# MNXR134891_c
# MNXR134891
# MNXR134870_c
# MNXR134870
# MNXR134939_c
# MNXR134939
# MNXR135993_c
# MNXR135993
# MNXR134973_c
# MNXR134973
# MNXR134874_c
# MNXR134874
# MNXR100607_c
# MNXR100607
# bio
# b
# EX_cpd00067_e
# EX_cpd00067
# EX_cpd00182_e
# EX_cpd00182
# EX_cpd00106_e
# EX_cpd00106
# EX_cpd00075_e
# EX_cpd00075
# EX_cpd00064_e
# EX_cpd00064
# EX_cpd08636_c
# EX_cpd08636
# EX_cpd00036_e
# EX_cpd00036
# EX_cpd11576_e
# EX_cpd11576
# EX_cpd04097_e
# EX_cpd04097
# EX_cpd11585_e
# EX_cpd11585
# EX_cpd00412_e
# EX_cpd00412
# EX_cpd11582_e
# EX_cpd11582
# EX_cpd00012_e
# EX_cpd00012
# EX_cpd11586_e
# EX_cpd11586
# EX_cpd01030_e
# EX_cpd01030
# EX_cpd00129_e
# EX_cpd00129
# EX_cpd00971_e
# EX_cpd00971
# EX_cpd01012_e
# EX_cpd01012
# EX_cpd00635_e
# EX_cpd00635
# EX_cpd00246_e
# EX_cpd00246
# EX_cpd00276_e
# EX_cpd00276
# EX_cpd00082_e
# EX_cpd00082
# EX_cpd00001_e
# EX_cpd00001
# EX_cpd00023_e
# EX_cpd00023
# EX_cpd00367_e
# EX_cpd00367
# EX_cpd00058_e
# EX_cpd00058
# EX_cpd00080_e
# EX_cpd00080
# EX_cpd00107_e
# EX_cpd00107
# EX_cpd00184_e
# EX_cpd00184
# EX_cpd00314_e
# EX_cpd00314
# EX_cpd01017_e
# EX_cpd01017
# EX_cpd00797_e
# EX_cpd00797
# EX_cpd00013_e
# EX_cpd00013
# EX_cpd00051_e
# EX_cpd00051
# EX_cpd10515_e
# EX_cpd10515
# EX_cpd00308_e
# EX_cpd00308
# EX_cpd00179_e
# EX_cpd00179
# EX_cpd00100_e
# EX_cpd00100
# EX_cpd11591_e
# EX_cpd11591
# EX_cpd00009_e
# EX_cpd00009
# EX_cpd00060_e
# EX_cpd00060
# EX_cpd00438_e
# EX_cpd00438
# EX_cpd00034_e
# EX_cpd00034
# EX_cpd00249_e
# EX_cpd00249
# EX_cpd00214_e
# EX_cpd00214
# EX_cpd00119_e
# EX_cpd00119
# EX_cpd11593_e
# EX_cpd11593
# EX_cpd00654_e
# EX_cpd00654
# EX_cpd00076_e
# EX_cpd00076
# EX_cpd00322_e
# EX_cpd00322
# EX_cpd01171_e
# EX_cpd01171
# EX_cpd00210_e
# EX_cpd00210
# EX_cpd15302_c
# EX_cpd15302
# EX_cpd15605_e
# EX_cpd15605
# EX_cpd00264_e
# EX_cpd00264
# EX_cpd00054_e
# EX_cpd00054
# EX_cpd00644_e
# EX_cpd00644
# EX_cpd00637_e
# EX_cpd00637
# EX_cpd00041_e
# EX_cpd00041
# EX_cpd00122_e
# EX_cpd00122
# EX_cpd00035_e
# EX_cpd00035
# EX_cpd15603_e
# EX_cpd15603
# EX_cpd00039_e
# EX_cpd00039
# EX_cpd03696_e
# EX_cpd03696
# EX_cpd00277_e
# EX_cpd00277
# EX_cpd00118_e
# EX_cpd00118
# EX_cpd00309_e
# EX_cpd00309
# EX_cpd11580_e
# EX_cpd11580
# EX_cpd01092_e
# EX_cpd01092
# EX_cpd03343_e
# EX_cpd03343
# EX_cpd03279_e
# EX_cpd03279
# EX_cpd00224_e
# EX_cpd00224
# EX_cpd01262_e
# EX_cpd01262
# EX_cpd00137_e
# EX_cpd00137
# EX_cpd10516_e
# EX_cpd10516
# EX_cpd00588_e
# EX_cpd00588
# EX_cpd00423_e
# EX_cpd00423
# EX_cpd00117_e
# EX_cpd00117
# EX_cpd00254_e
# EX_cpd00254
# EX_cpd00138_e
# EX_cpd00138
# EX_cpd02701_c
# EX_cpd02701
# EX_cpd01242_e
# EX_cpd01242
# EX_cpd00159_e
# EX_cpd00159
# EX_cpd00540_e
# EX_cpd00540
# EX_cpd00065_e
# EX_cpd00065
# EX_cpd00047_e
# EX_cpd00047
# EX_cpd15606_e
# EX_cpd15606
# EX_cpd00048_e
# EX_cpd00048
# EX_cpd03847_e
# EX_cpd03847
# EX_cpd00149_e
# EX_cpd00149
# EX_cpd15353_e
# EX_cpd15353
# EX_cpd15352_e
# EX_cpd15352
# EX_cpd01914_e
# EX_cpd01914
# EX_cpd00531_e
# EX_cpd00531
# EX_cpd11583_e
# EX_cpd11583
# EX_cpd00162_e
# EX_cpd00162
# EX_cpd11589_e
# EX_cpd11589
# EX_cpd00027_e
# EX_cpd00027
# EX_cpd03725_e
# EX_cpd03725
# EX_cpd00209_e
# EX_cpd00209
# EX_cpd00794_e
# EX_cpd00794
# EX_cpd00105_e
# EX_cpd00105
# EX_cpd00226_e
# EX_cpd00226
# EX_cpd11588_e
# EX_cpd11588
# EX_cpd01329_e
# EX_cpd01329
# EX_cpd15604_e
# EX_cpd15604
# EX_cpd01015_e
# EX_cpd01015
# EX_cpd00069_e
# EX_cpd00069
# EX_cpd00205_e
# EX_cpd00205
# EX_cpd00007_e
# EX_cpd00007
# EX_cpd03424_e
# EX_cpd03424
# EX_cpd00098_e
# EX_cpd00098
# EX_cpd11592_e
# EX_cpd11592
# EX_cpd00156_e
# EX_cpd00156
# EX_cpd11587_e
# EX_cpd11587
# EX_cpd00092_e
# EX_cpd00092
# EX_cpd11590_e
# EX_cpd11590
# EX_cpd11581_e
# EX_cpd11581
# EX_cpd15499_e
# EX_cpd15499
# EX_cpd15500_e
# EX_cpd15500
# EX_cpd01080_e
# EX_cpd01080
# EX_cpd11584_e
# EX_cpd11584
# EX_cpd00305_e
# EX_cpd00305
# EX_cpd00121_e
# EX_cpd00121
# EX_cpd00011_e
# EX_cpd00011
# EX_cpd11416_c
# EX_cpd11416
# EX_cpd00099_e
# EX_cpd00099
# EX_cpd00063_e
# EX_cpd00063
# EX_cpd00030_e
# EX_cpd00030

# %%
#write_sbml_model(model_new, "/Users/lizrad/Documents/Vibrio_folder/iVnat_newbigg.xml")
